# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import torch
from sklearn.preprocessing import StandardScaler
from typing import Tuple

# %%
dict_params = {'data': {'len_input': 100, 'horizon_forecast': 20, 'size_train': 0.8, 'size_valid': 0.2},
               'model': {'stack_1': {'kernel_size_pool': 16, 'expr_ratio_m1': 16}, 'stack_2': {'kernel_size_pool': 4, 'expr_ratio_m1': 4},
                         'stack_3': {'kernel_size_pool': 1, 'expr_ratio_m1': 1}, 'n_neur_hidden': 200, 'frac_dropout': 0.2, 'stride_maxpool': 1},
               'training': {'batch_size': 256, 'n_epochs': 500, 'patience': 50, 'min_delta_loss_perc': 0.01}}

# %%
class Block(torch.nn.Module):
    def __init__(self, kernel_size_pool: int, expr_ratio_m1: int, dict_params: dict, num_features: int) -> None:
        '''
        Block of the N-HiTS architecture.
        
        Args:
            kernel_size_pool: Kernel size of the MaxPool layer.
            expr_ratio_m1: Inverse of the expressiveness ratio; it should be greater than 1.
            dict_params: Dictionary containing the configuration settings.
            num_features: Number of features of the input series.
            
        Returns: None.
        '''
        super().__init__()
        #
        self.len_input = dict_params['data']['len_input']
        self.horizon_forecast = dict_params['data']['horizon_forecast']
        n_neur_hidden = dict_params['model']['n_neur_hidden']
        frac_dropout = dict_params['model']['frac_dropout']
        # dimension of theta_f
        self.dim_theta_f = int(np.ceil(self.horizon_forecast/expr_ratio_m1))
        # hidden layers of the FC stack
        self.max_pool = torch.nn.MaxPool1d(kernel_size = kernel_size_pool, stride = dict_params['model']['stride_maxpool'])
        self.dense_hid_1 = torch.nn.Linear(in_features = int(np.floor((self.len_input - kernel_size_pool)/dict_params['model']['stride_maxpool'] + 1)),
                                           out_features = n_neur_hidden)
        self.dense_hid_2 = torch.nn.Linear(in_features = n_neur_hidden, out_features = n_neur_hidden)
        self.relu = torch.nn.ReLU()
        self.dropout = torch.nn.Dropout(p = frac_dropout)
        self.batch_norm_1 = torch.nn.BatchNorm1d(n_neur_hidden)
        self.batch_norm_2 = torch.nn.BatchNorm1d(n_neur_hidden)
        # dense layer for producing the theta's
        self.dense_theta_b = torch.nn.Linear(in_features = n_neur_hidden, out_features = self.len_input, bias = False)
        self.dense_theta_f = torch.nn.Linear(in_features = n_neur_hidden, out_features = self.dim_theta_f, bias = False)
        
    def forward(self, x):
        x = x.reshape(x.shape[0], -1)
        y = self.max_pool(x)
        #
        y = self.dense_hid_1(y)
        y = self.batch_norm_1(y)
        y = self.relu(y)
        y = self.dropout(y)
        y = self.dense_hid_2(y)
        y = self.batch_norm_2(y)
        y = self.relu(y)
        y = self.dropout(y)
        # compute theta's
        theta_b = self.dense_theta_b(y)
        theta_f = self.dense_theta_f(y)
        # compute backcast
        x_hat = theta_b.reshape(*theta_b.shape, 1)
        # compute forecast
        y_hat = torch.nn.functional.interpolate(input = theta_f.reshape(*theta_f.shape, 1).transpose(1, 2), size = self.horizon_forecast).transpose(1, 2)
        #
        return x_hat, y_hat

class Stack(torch.nn.Module):
    def __init__(self, stack_number: int, dict_params: dict, num_features: int) -> None:
        '''
        Stack of the N-HiTS architecture.
        
        Args:
            stack_number: Integer indicating the block index in the stack, starting from 1.
            dict_params: Dictionary containing the configuration settings.
            num_features: Number of features of the input series.
            
        Returns: None
        '''
        super().__init__()
        stack_params = dict_params['model'][f'stack_{stack_number}']
        kernel_size_pool = stack_params['kernel_size_pool']
        expr_ratio_m1 = stack_params['expr_ratio_m1']
        #
        self.block = Block(kernel_size_pool = kernel_size_pool, expr_ratio_m1 = expr_ratio_m1, dict_params = dict_params,
                           num_features = num_features)
        
    def forward(self, x):
        x_hat, y = self.block(x)
        x = x - x_hat
        #
        x_hat = x
        y_hat = y
        return x_hat, y_hat

class NHiTS(torch.nn.Module):
    def __init__(self, dict_params: dict, num_features: int) -> None:
        '''
        N-HiTS architecture.
        
        Args:
            dict_params: Dictionary containing the configuration settings.
            num_features: Number of features of the input series.
            
        Returns: None
        '''
        super().__init__()
        #
        self.stack_1 = Stack(stack_number = 1, dict_params = dict_params, num_features = num_features)
        self.stack_2 = Stack(stack_number = 2, dict_params = dict_params, num_features = num_features)
        self.stack_3 = Stack(stack_number = 3, dict_params = dict_params, num_features = num_features)
        
    def forward(self, x):
        # first stack
        x_hat, y_hat_1 = self.stack_1(x)
        x = x - x_hat
        # second stack
        x_hat, y_hat_2 = self.stack_2(x)
        x = x - x_hat
        # third stack
        _, y_hat_3 = self.stack_3(x)
        #
        return y_hat_1, y_hat_2, y_hat_3

# %%
def train_test_splitting(df: pd.DataFrame, dict_params: dict) -> (pd.DataFrame, pd.DataFrame, pd.DataFrame):
    '''
    Function to split data in training, validation and test set.

    Args:
        df: Dataframe containing time series. The column representing the main series should be called `y`.
        dict_params: Dictionary containing information about the model architecture.

    Returns:
        df_train: Dataframe corresponding to training set.
        df_valid: Dataframe corresponding to validation set.
        df_test: Dataframe corresponding to test set.
    '''
    df_train = df.iloc[:int(df.shape[0]*dict_params['data']['size_train'])].copy().reset_index(drop = True)
    df_test = df.iloc[int(df.shape[0]*dict_params['data']['size_train']):].reset_index(drop = True).copy().reset_index(drop = True)
    df_valid = df_train.iloc[int(df_train.shape[0]*(1 - dict_params['data']['size_valid'])):].copy().reset_index(drop = True)
    df_train = df_train.iloc[:int(df_train.shape[0]*(1 - dict_params['data']['size_valid']))].copy().reset_index(drop = True)
    # rescale data
    scaler = StandardScaler().fit(df_train[['y']])
    df_train[['y']] = scaler.transform(df_train[['y']])
    df_valid[['y']] = scaler.transform(df_valid[['y']])
    df_test[['y']] = scaler.transform(df_test[['y']])
    #
    return df_train, df_valid, df_test, scaler

# %%
def get_x_y(df: pd.DataFrame, df_future: pd.DataFrame, dict_params: dict, test_set: bool = False,
            horizon_forecast: int = None) -> (torch.tensor, torch.tensor, np.array, np.array):
    '''
    Function obtain a tensor of regressors and one of target series.

    Args:
        df: Dataframe containing time series. The column representing the main series should be called `y`.
        df_future: Same as `df`, but corresponding to its future (e.g., `df_valid` could be the "future" of `df_train`).
        dict_params: Dictionary containing information about the model architecture.
        test_set: Whether `df` is the dataframe corresponding to test set.
        horizon_forecast: Length of the series to be predicted.

    Returns:
        x: Tensor representing regressors.
        y: Tensor representing target time series.
        date_x: Array containing the dates corresponding to the elements of `x`.
        date_y: Array containing the dates corresponding to the elements of `y`.
    '''
    dict_params = dict_params['data']
    #
    len_input = dict_params['len_input']
    if (horizon_forecast is None) or (horizon_forecast >= len_input):
        horizon_forecast = len_input
    #
    df_present = df.copy()
    if test_set == False:
        df_future = pd.concat((df_present, df_future)).copy().shift(-len_input)
        df_future = df_future.iloc[:df_present.shape[0]].reset_index(drop = True)
    else:
        df_future = df_present.copy().shift(-len_input).dropna()
        df_present = df_present.iloc[:df_future.shape[0]]
    #
    x = np.array([df_present.loc[i: i + len_input - 1,
                                 [col for col in df_present.columns if col != 'date']].values for i in range(df_present.shape[0] - len_input)])
    y = np.array([df_future.loc[i: i + horizon_forecast - 1, ['y']].values for i in range(df_future.shape[0] - horizon_forecast)])
    date_x = np.array([df_present.loc[i: i + len_input - 1, 'date'].values for i in range(df_present.shape[0] - len_input)])
    date_y = np.array([df_future.loc[i: i + horizon_forecast - 1, 'date'].values for i in range(df_future.shape[0] - horizon_forecast)])
    #
    y = y[:x.shape[0]]
    date_y = date_y[:date_x.shape[0]]
    #
    x = torch.tensor(x.astype(np.float32))
    y = torch.tensor(y.astype(np.float32))
    #
    date_x = date_x.reshape(x.shape[0], -1, 1)
    date_y = date_y.reshape(y.shape[0], -1, 1)
    #
    return x, y, date_x, date_y

# %%
class CreateDataset(torch.utils.data.Dataset):
    def __init__(self, x, y):
        '''
        Class to create a PyTorch dataset.
        
        Args:
            x: Tensor representing regressors.
            y: Tensor representing target time series.
            
        Returns: None.
        '''
        self.x = x
        self.y = y
    
    def __len__(self):
        return self.x.shape[0]
        
    def __getitem__(self, idx):
        return self.x[idx], self.y[idx]

# %%
class TrainNHiTS:
    def __init__(self, model: torch.nn.Module, dict_params: dict, dataloader_train: torch.utils.data.DataLoader, dataloader_valid: torch.utils.data.DataLoader):
        '''
        Class to train the N-HiTS model.
        
        Args:
            model: PyTorch model.
            dict_params: Dictionary containing information about the model architecture.
            dataloader_train: Dataloader containing training data.
            dataloader_valid: Dataloader containing validation data.
            
        Returns: None.
        '''
        self.model = model
        self.dict_params = dict_params
        self.loss_func = torch.nn.MSELoss()
        self.optimizer = torch.optim.Adam(params = model.parameters())
        self.scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer = self.optimizer, factor = 0.5)
        self.dataloader_train = dataloader_train
        self.dataloader_valid = dataloader_valid

    def _model_on_batch(self, batch: tuple, training: bool, loss_epoch: float) -> float:
        '''
        Function to perform training on a single batch of data.
        
        Args:
            batch: Batch of data to use for training/evaluation.
            training: Whether to perform training (if not, evaluation is understood).
            loss_epoch: Loss of the current epoch.
            
        Returns:
            loss: Value of the loss function.
        '''
        if training == True:
            self.optimizer.zero_grad()
        #
        x, y_true = batch
        x = x.to('cpu')
        y_true = y_true.to('cpu')
        y_hat_1, y_hat_2, y_hat_3 = self.model(x)
        y_hat_1 = y_hat_1.to('cpu')
        y_hat_2 = y_hat_2.to('cpu')
        y_hat_3 = y_hat_3.to('cpu')
        #
        loss = self.loss_func(y_hat_1 + y_hat_2 + y_hat_3, y_true)
        #
        if training == True:
            loss.backward()
            self.optimizer.step()
        #
        return loss.item()

    def _train(self) -> float:
        '''
        Function to train the TCN model on a single epoch.
        
        Args: None.
            
        Returns:
            loss: Value of the training loss function per batch.
        '''
        self.model.train()
        loss_epoch = 0
        for batch in self.dataloader_train:
            loss_epoch += self._model_on_batch(batch = batch, training = True, loss_epoch = loss_epoch)
        return loss_epoch/len(self.dataloader_train)

    def _eval(self) -> float:
        '''
        Function to evaluate the TCN model on the validation set on a single epoch.
        
        Args: None.
            
        Returns:
            loss: Value of the validation loss function per batch.
        '''
        self.model.eval()
        loss_epoch = 0
        with torch.no_grad():
            for batch in self.dataloader_valid:
                loss_epoch += self._model_on_batch(batch = batch, training = False, loss_epoch = loss_epoch)
        return loss_epoch/len(self.dataloader_valid)

    def train_model(self) -> (torch.nn.Module, list, list):
        '''
        Function to train the TCN model.
        
        Args: None.
            
        Returns:
            model: Trained N-HiTS model.
            list_loss_train: List of training loss function across the epochs.
            list_loss_valid: List of validation loss function across the epochs.
        '''
        dict_params = self.dict_params
        n_epochs = dict_params['training']['n_epochs']
        list_loss_train, list_loss_valid = [], []
        counter_patience = 0
        for epoch in range(1, n_epochs + 1):
            loss_train = self._train()
            loss_valid = self._eval()
            #
            if (len(list_loss_valid) > 0) and (loss_valid >= np.min(list_loss_valid)*(1 - dict_params['training']['min_delta_loss_perc'])):
                counter_patience += 1
            if (len(list_loss_valid) == 0) or ((len(list_loss_valid) > 0) and (loss_valid < np.min(list_loss_valid))):
                counter_patience = 0
                torch.save(self.model.state_dict(), '../data/artifacts/weights.p')
            if counter_patience >= dict_params['training']['patience']:
                print(f'Training stopped at epoch {epoch}. Restoring weights from epoch {np.argmin(list_loss_valid) + 1}.')
                self.model.load_state_dict(torch.load('../data/artifacts/weights.p'))
                break
            #
            print(f'Epoch {epoch}: training loss = {loss_train:.4f}, validation loss = {loss_valid:.4f}, patience counter = {counter_patience}.')
            self.scheduler.step(loss_valid)
            #
            list_loss_train.append(loss_train)
            list_loss_valid.append(loss_valid)
        if epoch == n_epochs:
            self.model.load_state_dict(torch.load('../data/artifacts/weights.p'))
        return self.model, list_loss_train, list_loss_valid

# %%
def get_y_true_y_hat(model: torch.nn.Module, x: torch.tensor, y: torch.tensor, date_y: np.array,
                     scaler: sklearn.preprocessing.StandardScaler) -> (np.array, np.array, np.array):
    '''
    Function to get the real time series and its prediction.
    
    Args:
        model: Trained N-BEATS model.
        x: Tensor representing regressors.
        y: Tensor representing target time series.
        date_y: Array containing the dates corresponding to the elements of `y`.
        scaler: Scaled used to rescale data.
        
    Returns:
        y_true: Array containing the true values.
        y_hat_trend: Array containing the predicted trend.
        y_hat_seas: Array containing the predicted seasonality.
    '''
    list_date = []
    y_true = []
    y_hat_1, y_hat_2, y_hat_3 = [], [], []
    pred_1, pred_2, pred_3 = model(x)
    for i in range(np.unique(date_y).shape[0]):
        date = np.unique(date_y)[i]
        list_date.append(date)
        idx = np.where(date_y == date)
        y_true.append(y.numpy()[idx].mean())
        y_hat_1.append(pred_1.detach().numpy()[idx].mean())
        y_hat_2.append(pred_2.detach().numpy()[idx].mean())
        y_hat_3.append(pred_3.detach().numpy()[idx].mean())
    y_true = np.array(y_true)
    y_hat_1 = np.array(y_hat_1)
    y_hat_2 = np.array(y_hat_2)
    y_hat_3 = np.array(y_hat_3)
    # scale back
    y_true = scaler.inverse_transform(y_true.reshape(-1, 1)).ravel()
    y_hat_1 = scaler.inverse_transform(y_hat_1.reshape(-1, 1)).ravel()
    y_hat_2 = scaler.inverse_transform(y_hat_2.reshape(-1, 1)).ravel()
    y_hat_3 = scaler.inverse_transform(y_hat_3.reshape(-1, 1)).ravel()
    #
    return y_true, y_hat_1, y_hat_2, y_hat_3

# %%
def compute_mape(y_true: np.array, y_hat_1: np.array, y_hat_2: np.array, y_hat_3: np.array, scaler: sklearn.preprocessing.StandardScaler) -> float:
    '''
    Function to compute the MAPE.
    
    Args:
        y_true: Array containing the true values.
        y_hat_1: Array containing the first predicted component.
        y_hat_2: Array containing the second predicted component.
        y_hat_3: Array containing the third predicted component.
        scaler: Scaled used to rescale data.
        
    Returns:
        mape: MAPE computed from `y_true` and `y_hat`.
    '''
    y_hat = y_hat_1 + y_hat_2 + y_hat_3 - 2*scaler.mean_
    mape = np.mean(abs(y_true[y_true > 0] - y_hat[y_true > 0])/y_true[y_true > 0])
    return mape

# %%
df = pd.read_csv('../data/raw/train.csv', parse_dates = ['date'], index_col = 'id')
df = df.groupby(['date', 'family']).agg({'sales': 'sum'}).reset_index()
# add all dates
df_temp = []
for family in df['family'].unique():
    df_temp.append(pd.DataFrame({'date': pd.date_range(df['date'].min(), df['date'].max())}).merge(df[df['family'] == family],
                                                                                                on = 'date', how = 'left'))
    df_temp[-1]['family'] = family
    df_temp[-1]['sales'] = df_temp[-1]['sales'].ffill()
df = pd.concat(df_temp).reset_index(drop = True)
del df_temp
df = df.rename(columns = {'sales': 'y'})
# perform train-test splitting
df_train, df_valid, df_test, scaler = train_test_splitting(df = df[df['family'] == 'AUTOMOTIVE'].reset_index(drop = True).drop('family', axis = 1),
                                                        dict_params = dict_params)
#
horizon_forecast = dict_params['data']['horizon_forecast']
# training set data
x_train, y_train, date_x_train, date_y_train = get_x_y(df = df_train, df_future = df_valid, dict_params = dict_params,
                                                       test_set = False, horizon_forecast = horizon_forecast)
# validation set data
x_valid, y_valid, date_x_valid, date_y_valid = get_x_y(df = df_valid, df_future = df_test, dict_params = dict_params,
                                                       test_set = False, horizon_forecast = horizon_forecast)
# test set data
x_test, y_test, date_x_test, date_y_test = get_x_y(df = df_test, df_future = None, dict_params = dict_params, test_set = True,
                                                   horizon_forecast = horizon_forecast)
# create datasets and dataloader
dataset_train = CreateDataset(x = x_train, y = y_train)
dataset_valid = CreateDataset(x = x_valid, y = y_valid)
dataloader_train = torch.utils.data.DataLoader(dataset_train, batch_size = dict_params['training']['batch_size'], shuffle = True)
dataloader_valid = torch.utils.data.DataLoader(dataset_valid, batch_size = dict_params['training']['batch_size'], shuffle = False)
# train model
model = NHiTS(dict_params = dict_params, num_features = x_train.shape[2])
model, list_loss_train, list_loss_valid = TrainNHiTS(model = model, dict_params = dict_params, dataloader_train = dataloader_train, dataloader_valid = dataloader_train).train_model()
# evaluate results
model = NHiTS(dict_params = dict_params, num_features = x_train.shape[2])
model.load_state_dict(torch.load('../data/artifacts/weights.p'))
model.eval()
# get time series and the corresponding predictions
y_true_train, y_hat_1_train, y_hat_2_train, y_hat_3_train = get_y_true_y_hat(model = model, x = x_train, y = y_train, date_y = date_y_train, scaler = scaler)
y_true_valid, y_hat_1_valid, y_hat_2_valid, y_hat_3_valid = get_y_true_y_hat(model = model, x = x_valid, y = y_valid, date_y = date_y_valid, scaler = scaler)
y_true_test, y_hat_1_test, y_hat_2_test, y_hat_3_test = get_y_true_y_hat(model = model, x = x_test, y = y_test, date_y = date_y_test, scaler = scaler)
# compute mape on training, validation and test set
mape_train = compute_mape(y_true = y_true_train, y_hat_1 = y_hat_1_train, y_hat_2 = y_hat_2_train, y_hat_3 = y_hat_3_train, scaler = scaler)
mape_valid = compute_mape(y_true = y_true_valid, y_hat_1 = y_hat_1_valid, y_hat_2 = y_hat_2_valid, y_hat_3 = y_hat_3_valid, scaler = scaler)
mape_test = compute_mape(y_true = y_true_test, y_hat_1 = y_hat_1_test, y_hat_2 = y_hat_2_test, y_hat_3 = y_hat_3_test, scaler = scaler)
#
plt.figure(figsize = [10, 6])
plt.plot(np.unique(date_y_test), y_true_test, label = 'True', color = 'r')
plt.plot(np.unique(date_y_test), y_hat_1_test + y_hat_2_test + y_hat_3_test - 2*scaler.mean_, label = 'Predicted', color = 'b')
plt.plot(np.unique(date_y_test), y_hat_1_test, label = 'First predicted component', color = 'b', ls = '--')
plt.plot(np.unique(date_y_test), y_hat_2_test - scaler.mean_, label = 'Second predicted component', color = 'b', ls = '-.')
plt.plot(np.unique(date_y_test), y_hat_3_test - scaler.mean_, label = 'Third predicted component', color = 'b', ls = ':')
plt.xlabel('Date', fontsize = 16)
plt.ylabel('Sales', fontsize = 16)
plt.xticks(rotation = 45)
plt.legend()
plt.savefig('../docs/figures_for_readme/result', bbox_inches = 'tight')
#
plt.figure(figsize = [10, 6])
plt.plot(list_loss_train, c = 'r', label = 'Training')
plt.plot(list_loss_valid, c = 'b', label = 'Validation')
plt.xlabel('Epoch', fontsize = 16)
plt.ylabel('Loss', fontsize = 16)
plt.legend()
plt.savefig('../docs/figures_for_readme/loss', bbox_inches = 'tight')
plt.show()
# Out:
# Epoch 1: training loss = 1.3417, validation loss = 0.9542, patience counter = 0.
# Epoch 2: training loss = 1.1269, validation loss = 0.9501, patience counter = 0.
# Epoch 3: training loss = 1.0681, validation loss = 0.9131, patience counter = 0.
# Epoch 4: training loss = 1.0173, validation loss = 0.8907, patience counter = 0.
# Epoch 5: training loss = 0.9873, validation loss = 0.8603, patience counter = 0.
# Epoch 6: training loss = 0.9437, validation loss = 0.8353, patience counter = 0.
# Epoch 7: training loss = 0.9263, validation loss = 0.8112, patience counter = 0.
# Epoch 8: training loss = 0.9165, validation loss = 0.8068, patience counter = 0.
# Epoch 9: training loss = 0.8914, validation loss = 0.7791, patience counter = 0.
# Epoch 10: training loss = 0.8683, validation loss = 0.7649, patience counter = 0.
# Epoch 11: training loss = 0.8567, validation loss = 0.7564, patience counter = 0.
# Epoch 12: training loss = 0.8585, validation loss = 0.7363, patience counter = 0.
# Epoch 13: training loss = 0.8359, validation loss = 0.7255, patience counter = 0.
# Epoch 14: training loss = 0.8234, validation loss = 0.7238, patience counter = 0.
# Epoch 15: training loss = 0.8017, validation loss = 0.7029, patience counter = 0.
# Epoch 16: training loss = 0.7789, validation loss = 0.6982, patience counter = 0.
# Epoch 17: training loss = 0.7537, validation loss = 0.6690, patience counter = 0.
# Epoch 18: training loss = 0.7435, validation loss = 0.6436, patience counter = 0.
# Epoch 19: training loss = 0.7178, validation loss = 0.6000, patience counter = 0.
# Epoch 20: training loss = 0.6733, validation loss = 0.6124, patience counter = 1.
# Epoch 21: training loss = 0.6457, validation loss = 0.5776, patience counter = 0.
# Epoch 22: training loss = 0.6174, validation loss = 0.5466, patience counter = 0.
# Epoch 23: training loss = 0.5923, validation loss = 0.4513, patience counter = 0.
# Epoch 24: training loss = 0.5569, validation loss = 0.4657, patience counter = 1.
# Epoch 25: training loss = 0.5398, validation loss = 0.3890, patience counter = 0.
# Epoch 26: training loss = 0.5097, validation loss = 0.4070, patience counter = 1.
# Epoch 27: training loss = 0.5094, validation loss = 0.4933, patience counter = 2.
# Epoch 28: training loss = 0.4866, validation loss = 0.6001, patience counter = 3.
# Epoch 29: training loss = 0.4829, validation loss = 0.4675, patience counter = 4.
# Epoch 30: training loss = 0.4811, validation loss = 0.6514, patience counter = 5.
# Epoch 31: training loss = 0.4613, validation loss = 0.4604, patience counter = 6.
# Epoch 32: training loss = 0.4431, validation loss = 0.3876, patience counter = 0.
# Epoch 33: training loss = 0.4466, validation loss = 0.4288, patience counter = 1.
# Epoch 34: training loss = 0.4338, validation loss = 0.3132, patience counter = 0.
# Epoch 35: training loss = 0.4262, validation loss = 0.3322, patience counter = 1.
# Epoch 36: training loss = 0.4263, validation loss = 0.3670, patience counter = 2.
# Epoch 37: training loss = 0.4082, validation loss = 0.3207, patience counter = 3.
# Epoch 38: training loss = 0.4078, validation loss = 0.2782, patience counter = 0.
# Epoch 39: training loss = 0.3928, validation loss = 0.2823, patience counter = 1.
# Epoch 40: training loss = 0.3977, validation loss = 0.2912, patience counter = 2.
# Epoch 41: training loss = 0.3919, validation loss = 0.2860, patience counter = 3.
# Epoch 42: training loss = 0.3875, validation loss = 0.3104, patience counter = 4.
# Epoch 43: training loss = 0.3852, validation loss = 0.2666, patience counter = 0.
# Epoch 44: training loss = 0.3643, validation loss = 0.3044, patience counter = 1.
# Epoch 45: training loss = 0.3713, validation loss = 0.2796, patience counter = 2.
# Epoch 46: training loss = 0.3668, validation loss = 0.3470, patience counter = 3.
# Epoch 47: training loss = 0.3709, validation loss = 0.4183, patience counter = 4.
# Epoch 48: training loss = 0.3735, validation loss = 0.3060, patience counter = 5.
# Epoch 49: training loss = 0.3703, validation loss = 0.2731, patience counter = 6.
# Epoch 50: training loss = 0.3621, validation loss = 0.3135, patience counter = 7.
# Epoch 51: training loss = 0.3582, validation loss = 0.2722, patience counter = 8.
# Epoch 52: training loss = 0.3512, validation loss = 0.2647, patience counter = 0.
# Epoch 53: training loss = 0.3581, validation loss = 0.2752, patience counter = 1.
# Epoch 54: training loss = 0.3513, validation loss = 0.2972, patience counter = 2.
# Epoch 55: training loss = 0.3501, validation loss = 0.2703, patience counter = 3.
# Epoch 56: training loss = 0.3419, validation loss = 0.2906, patience counter = 4.
# Epoch 57: training loss = 0.3320, validation loss = 0.2636, patience counter = 0.
# Epoch 58: training loss = 0.3332, validation loss = 0.2554, patience counter = 0.
# Epoch 59: training loss = 0.3423, validation loss = 0.2733, patience counter = 1.
# Epoch 60: training loss = 0.3292, validation loss = 0.2515, patience counter = 0.
# Epoch 61: training loss = 0.3302, validation loss = 0.2441, patience counter = 0.
# Epoch 62: training loss = 0.3333, validation loss = 0.2502, patience counter = 1.
# Epoch 63: training loss = 0.3275, validation loss = 0.2411, patience counter = 0.
# Epoch 64: training loss = 0.3280, validation loss = 0.2449, patience counter = 1.
# Epoch 65: training loss = 0.3296, validation loss = 0.2442, patience counter = 2.
# Epoch 66: training loss = 0.3333, validation loss = 0.2437, patience counter = 3.
# Epoch 67: training loss = 0.3230, validation loss = 0.2612, patience counter = 4.
# Epoch 68: training loss = 0.3255, validation loss = 0.2265, patience counter = 0.
# Epoch 69: training loss = 0.3161, validation loss = 0.2415, patience counter = 1.
# Epoch 70: training loss = 0.3137, validation loss = 0.2368, patience counter = 2.
# Epoch 71: training loss = 0.3107, validation loss = 0.2253, patience counter = 0.
# Epoch 72: training loss = 0.3119, validation loss = 0.2270, patience counter = 1.
# Epoch 73: training loss = 0.3078, validation loss = 0.2288, patience counter = 2.
# Epoch 74: training loss = 0.3095, validation loss = 0.2382, patience counter = 3.
# Epoch 75: training loss = 0.3095, validation loss = 0.2373, patience counter = 4.
# Epoch 76: training loss = 0.3153, validation loss = 0.2308, patience counter = 5.
# Epoch 77: training loss = 0.3064, validation loss = 0.2313, patience counter = 6.
# Epoch 78: training loss = 0.3054, validation loss = 0.2226, patience counter = 0.
# Epoch 79: training loss = 0.3072, validation loss = 0.2220, patience counter = 0.
# Epoch 80: training loss = 0.3054, validation loss = 0.2174, patience counter = 0.
# Epoch 81: training loss = 0.3034, validation loss = 0.2442, patience counter = 1.
# Epoch 82: training loss = 0.2986, validation loss = 0.2374, patience counter = 2.
# Epoch 83: training loss = 0.3044, validation loss = 0.2761, patience counter = 3.
# Epoch 84: training loss = 0.3055, validation loss = 0.2334, patience counter = 4.
# Epoch 85: training loss = 0.2909, validation loss = 0.2335, patience counter = 5.
# Epoch 86: training loss = 0.2970, validation loss = 0.2212, patience counter = 6.
# Epoch 87: training loss = 0.2916, validation loss = 0.2335, patience counter = 7.
# Epoch 88: training loss = 0.2933, validation loss = 0.2441, patience counter = 8.
# Epoch 89: training loss = 0.2896, validation loss = 0.2439, patience counter = 9.
# Epoch 90: training loss = 0.2909, validation loss = 0.2426, patience counter = 10.
# Epoch 91: training loss = 0.2896, validation loss = 0.2293, patience counter = 11.
# Epoch 92: training loss = 0.2818, validation loss = 0.2060, patience counter = 0.
# Epoch 93: training loss = 0.2872, validation loss = 0.2116, patience counter = 1.
# Epoch 94: training loss = 0.2846, validation loss = 0.2065, patience counter = 2.
# Epoch 95: training loss = 0.2838, validation loss = 0.1965, patience counter = 0.
# Epoch 96: training loss = 0.2793, validation loss = 0.1972, patience counter = 1.
# Epoch 97: training loss = 0.2826, validation loss = 0.2016, patience counter = 2.
# Epoch 98: training loss = 0.2751, validation loss = 0.1958, patience counter = 0.
# Epoch 99: training loss = 0.2899, validation loss = 0.1960, patience counter = 1.
# Epoch 100: training loss = 0.2720, validation loss = 0.1971, patience counter = 2.
# Epoch 101: training loss = 0.2787, validation loss = 0.1989, patience counter = 3.
# Epoch 102: training loss = 0.2779, validation loss = 0.2044, patience counter = 4.
# Epoch 103: training loss = 0.2720, validation loss = 0.1990, patience counter = 5.
# Epoch 104: training loss = 0.2794, validation loss = 0.1964, patience counter = 6.
# Epoch 105: training loss = 0.2737, validation loss = 0.1935, patience counter = 0.
# Epoch 106: training loss = 0.2752, validation loss = 0.1932, patience counter = 0.
# Epoch 107: training loss = 0.2845, validation loss = 0.1953, patience counter = 1.
# Epoch 108: training loss = 0.2733, validation loss = 0.2024, patience counter = 2.
# Epoch 109: training loss = 0.2734, validation loss = 0.2050, patience counter = 3.
# Epoch 110: training loss = 0.2763, validation loss = 0.2130, patience counter = 4.
# Epoch 111: training loss = 0.2759, validation loss = 0.1974, patience counter = 5.
# Epoch 112: training loss = 0.2689, validation loss = 0.1896, patience counter = 0.
# Epoch 113: training loss = 0.2680, validation loss = 0.1928, patience counter = 1.
# Epoch 114: training loss = 0.2648, validation loss = 0.1977, patience counter = 2.
# Epoch 115: training loss = 0.2739, validation loss = 0.1941, patience counter = 3.
# Epoch 116: training loss = 0.2660, validation loss = 0.1907, patience counter = 4.
# Epoch 117: training loss = 0.2685, validation loss = 0.1902, patience counter = 5.
# Epoch 118: training loss = 0.2673, validation loss = 0.1937, patience counter = 6.
# Epoch 119: training loss = 0.2729, validation loss = 0.1974, patience counter = 7.
# Epoch 120: training loss = 0.2743, validation loss = 0.1912, patience counter = 8.
# Epoch 121: training loss = 0.2681, validation loss = 0.1926, patience counter = 9.
# Epoch 122: training loss = 0.2764, validation loss = 0.1939, patience counter = 10.
# Epoch 123: training loss = 0.2717, validation loss = 0.1873, patience counter = 0.
# Epoch 124: training loss = 0.2627, validation loss = 0.1922, patience counter = 1.
# Epoch 125: training loss = 0.2567, validation loss = 0.1882, patience counter = 2.
# Epoch 126: training loss = 0.2680, validation loss = 0.1963, patience counter = 3.
# Epoch 127: training loss = 0.2661, validation loss = 0.1880, patience counter = 4.
# Epoch 128: training loss = 0.2703, validation loss = 0.1963, patience counter = 5.
# Epoch 129: training loss = 0.2587, validation loss = 0.1908, patience counter = 6.
# Epoch 130: training loss = 0.2635, validation loss = 0.1911, patience counter = 7.
# Epoch 131: training loss = 0.2659, validation loss = 0.1920, patience counter = 8.
# Epoch 132: training loss = 0.2728, validation loss = 0.1887, patience counter = 9.
# Epoch 133: training loss = 0.2572, validation loss = 0.1874, patience counter = 10.
# Epoch 134: training loss = 0.2653, validation loss = 0.1878, patience counter = 11.
# Epoch 135: training loss = 0.2586, validation loss = 0.1845, patience counter = 0.
# Epoch 136: training loss = 0.2577, validation loss = 0.1826, patience counter = 0.
# Epoch 137: training loss = 0.2531, validation loss = 0.1832, patience counter = 1.
# Epoch 138: training loss = 0.2564, validation loss = 0.1843, patience counter = 2.
# Epoch 139: training loss = 0.2518, validation loss = 0.1833, patience counter = 3.
# Epoch 140: training loss = 0.2586, validation loss = 0.1816, patience counter = 0.
# Epoch 141: training loss = 0.2606, validation loss = 0.1807, patience counter = 0.
# Epoch 142: training loss = 0.2548, validation loss = 0.1826, patience counter = 1.
# Epoch 143: training loss = 0.2544, validation loss = 0.1798, patience counter = 0.
# Epoch 144: training loss = 0.2616, validation loss = 0.1822, patience counter = 1.
# Epoch 145: training loss = 0.2534, validation loss = 0.1826, patience counter = 2.
# Epoch 146: training loss = 0.2529, validation loss = 0.1801, patience counter = 3.
# Epoch 147: training loss = 0.2543, validation loss = 0.1807, patience counter = 4.
# Epoch 148: training loss = 0.2608, validation loss = 0.1820, patience counter = 5.
# Epoch 149: training loss = 0.2580, validation loss = 0.1818, patience counter = 6.
# Epoch 150: training loss = 0.2548, validation loss = 0.1813, patience counter = 7.
# Epoch 151: training loss = 0.2580, validation loss = 0.1818, patience counter = 8.
# Epoch 152: training loss = 0.2546, validation loss = 0.1865, patience counter = 9.
# Epoch 153: training loss = 0.2593, validation loss = 0.1839, patience counter = 10.
# Epoch 154: training loss = 0.2558, validation loss = 0.1807, patience counter = 11.
# Epoch 155: training loss = 0.2539, validation loss = 0.1778, patience counter = 0.
# Epoch 156: training loss = 0.2571, validation loss = 0.1776, patience counter = 0.
# Epoch 157: training loss = 0.2556, validation loss = 0.1772, patience counter = 0.
# Epoch 158: training loss = 0.2533, validation loss = 0.1767, patience counter = 0.
# Epoch 159: training loss = 0.2581, validation loss = 0.1786, patience counter = 1.
# Epoch 160: training loss = 0.2525, validation loss = 0.1768, patience counter = 2.
# Epoch 161: training loss = 0.2491, validation loss = 0.1778, patience counter = 3.
# Epoch 162: training loss = 0.2502, validation loss = 0.1784, patience counter = 4.
# Epoch 163: training loss = 0.2518, validation loss = 0.1777, patience counter = 5.
# Epoch 164: training loss = 0.2544, validation loss = 0.1776, patience counter = 6.
# Epoch 165: training loss = 0.2498, validation loss = 0.1771, patience counter = 7.
# Epoch 166: training loss = 0.2514, validation loss = 0.1776, patience counter = 8.
# Epoch 167: training loss = 0.2517, validation loss = 0.1767, patience counter = 9.
# Epoch 168: training loss = 0.2480, validation loss = 0.1765, patience counter = 0.
# Epoch 169: training loss = 0.2511, validation loss = 0.1764, patience counter = 0.
# Epoch 170: training loss = 0.2516, validation loss = 0.1768, patience counter = 1.
# Epoch 171: training loss = 0.2526, validation loss = 0.1762, patience counter = 0.
# Epoch 172: training loss = 0.2467, validation loss = 0.1754, patience counter = 0.
# Epoch 173: training loss = 0.2527, validation loss = 0.1772, patience counter = 1.
# Epoch 174: training loss = 0.2469, validation loss = 0.1778, patience counter = 2.
# Epoch 175: training loss = 0.2488, validation loss = 0.1759, patience counter = 3.
# Epoch 176: training loss = 0.2493, validation loss = 0.1768, patience counter = 4.
# Epoch 177: training loss = 0.2500, validation loss = 0.1772, patience counter = 5.
# Epoch 178: training loss = 0.2527, validation loss = 0.1764, patience counter = 6.
# Epoch 179: training loss = 0.2491, validation loss = 0.1764, patience counter = 7.
# Epoch 180: training loss = 0.2529, validation loss = 0.1759, patience counter = 8.
# Epoch 181: training loss = 0.2498, validation loss = 0.1752, patience counter = 0.
# Epoch 182: training loss = 0.2468, validation loss = 0.1763, patience counter = 1.
# Epoch 183: training loss = 0.2508, validation loss = 0.1756, patience counter = 2.
# Epoch 184: training loss = 0.2512, validation loss = 0.1752, patience counter = 3.
# Epoch 185: training loss = 0.2489, validation loss = 0.1757, patience counter = 4.
# Epoch 186: training loss = 0.2479, validation loss = 0.1745, patience counter = 0.
# Epoch 187: training loss = 0.2487, validation loss = 0.1746, patience counter = 1.
# Epoch 188: training loss = 0.2450, validation loss = 0.1751, patience counter = 2.
# Epoch 189: training loss = 0.2530, validation loss = 0.1759, patience counter = 3.
# Epoch 190: training loss = 0.2496, validation loss = 0.1758, patience counter = 4.
# Epoch 191: training loss = 0.2489, validation loss = 0.1742, patience counter = 0.
# Epoch 192: training loss = 0.2460, validation loss = 0.1746, patience counter = 1.
# Epoch 193: training loss = 0.2514, validation loss = 0.1747, patience counter = 2.
# Epoch 194: training loss = 0.2501, validation loss = 0.1756, patience counter = 3.
# Epoch 195: training loss = 0.2509, validation loss = 0.1757, patience counter = 4.
# Epoch 196: training loss = 0.2442, validation loss = 0.1750, patience counter = 5.
# Epoch 197: training loss = 0.2468, validation loss = 0.1749, patience counter = 6.
# Epoch 198: training loss = 0.2465, validation loss = 0.1753, patience counter = 7.
# Epoch 199: training loss = 0.2470, validation loss = 0.1747, patience counter = 8.
# Epoch 200: training loss = 0.2467, validation loss = 0.1745, patience counter = 9.
# Epoch 201: training loss = 0.2436, validation loss = 0.1740, patience counter = 0.
# Epoch 202: training loss = 0.2463, validation loss = 0.1743, patience counter = 1.
# Epoch 203: training loss = 0.2432, validation loss = 0.1735, patience counter = 0.
# Epoch 204: training loss = 0.2421, validation loss = 0.1746, patience counter = 1.
# Epoch 205: training loss = 0.2462, validation loss = 0.1746, patience counter = 2.
# Epoch 206: training loss = 0.2425, validation loss = 0.1742, patience counter = 3.
# Epoch 207: training loss = 0.2408, validation loss = 0.1743, patience counter = 4.
# Epoch 208: training loss = 0.2462, validation loss = 0.1743, patience counter = 5.
# Epoch 209: training loss = 0.2447, validation loss = 0.1744, patience counter = 6.
# Epoch 210: training loss = 0.2537, validation loss = 0.1743, patience counter = 7.
# Epoch 211: training loss = 0.2449, validation loss = 0.1736, patience counter = 8.
# Epoch 212: training loss = 0.2450, validation loss = 0.1735, patience counter = 0.
# Epoch 213: training loss = 0.2442, validation loss = 0.1734, patience counter = 0.
# Epoch 214: training loss = 0.2392, validation loss = 0.1722, patience counter = 0.
# Epoch 215: training loss = 0.2498, validation loss = 0.1731, patience counter = 1.
# Epoch 216: training loss = 0.2493, validation loss = 0.1733, patience counter = 2.
# Epoch 217: training loss = 0.2370, validation loss = 0.1743, patience counter = 3.
# Epoch 218: training loss = 0.2430, validation loss = 0.1740, patience counter = 4.
# Epoch 219: training loss = 0.2476, validation loss = 0.1744, patience counter = 5.
# Epoch 220: training loss = 0.2453, validation loss = 0.1753, patience counter = 6.
# Epoch 221: training loss = 0.2432, validation loss = 0.1745, patience counter = 7.
# Epoch 222: training loss = 0.2416, validation loss = 0.1734, patience counter = 8.
# Epoch 223: training loss = 0.2486, validation loss = 0.1732, patience counter = 9.
# Epoch 224: training loss = 0.2428, validation loss = 0.1733, patience counter = 10.
# Epoch 225: training loss = 0.2452, validation loss = 0.1735, patience counter = 11.
# Epoch 226: training loss = 0.2487, validation loss = 0.1724, patience counter = 12.
# Epoch 227: training loss = 0.2459, validation loss = 0.1726, patience counter = 13.
# Epoch 228: training loss = 0.2481, validation loss = 0.1730, patience counter = 14.
# Epoch 229: training loss = 0.2413, validation loss = 0.1726, patience counter = 15.
# Epoch 230: training loss = 0.2520, validation loss = 0.1730, patience counter = 16.
# Epoch 231: training loss = 0.2410, validation loss = 0.1715, patience counter = 0.
# Epoch 232: training loss = 0.2433, validation loss = 0.1714, patience counter = 0.
# Epoch 233: training loss = 0.2406, validation loss = 0.1722, patience counter = 1.
# Epoch 234: training loss = 0.2469, validation loss = 0.1728, patience counter = 2.
# Epoch 235: training loss = 0.2431, validation loss = 0.1723, patience counter = 3.
# Epoch 236: training loss = 0.2428, validation loss = 0.1722, patience counter = 4.
# Epoch 237: training loss = 0.2468, validation loss = 0.1729, patience counter = 5.
# Epoch 238: training loss = 0.2410, validation loss = 0.1725, patience counter = 6.
# Epoch 239: training loss = 0.2421, validation loss = 0.1731, patience counter = 7.
# Epoch 240: training loss = 0.2430, validation loss = 0.1722, patience counter = 8.
# Epoch 241: training loss = 0.2419, validation loss = 0.1723, patience counter = 9.
# Epoch 242: training loss = 0.2364, validation loss = 0.1723, patience counter = 10.
# Epoch 243: training loss = 0.2436, validation loss = 0.1716, patience counter = 11.
# Epoch 244: training loss = 0.2429, validation loss = 0.1718, patience counter = 12.
# Epoch 245: training loss = 0.2497, validation loss = 0.1715, patience counter = 13.
# Epoch 246: training loss = 0.2401, validation loss = 0.1715, patience counter = 14.
# Epoch 247: training loss = 0.2492, validation loss = 0.1714, patience counter = 15.
# Epoch 248: training loss = 0.2418, validation loss = 0.1716, patience counter = 16.
# Epoch 249: training loss = 0.2478, validation loss = 0.1720, patience counter = 17.
# Epoch 250: training loss = 0.2396, validation loss = 0.1724, patience counter = 18.
# Epoch 251: training loss = 0.2484, validation loss = 0.1712, patience counter = 0.
# Epoch 252: training loss = 0.2401, validation loss = 0.1713, patience counter = 1.
# Epoch 253: training loss = 0.2416, validation loss = 0.1720, patience counter = 2.
# Epoch 254: training loss = 0.2423, validation loss = 0.1729, patience counter = 3.
# Epoch 255: training loss = 0.2441, validation loss = 0.1714, patience counter = 4.
# Epoch 256: training loss = 0.2422, validation loss = 0.1713, patience counter = 5.
# Epoch 257: training loss = 0.2433, validation loss = 0.1714, patience counter = 6.
# Epoch 258: training loss = 0.2481, validation loss = 0.1708, patience counter = 0.
# Epoch 259: training loss = 0.2432, validation loss = 0.1715, patience counter = 1.
# Epoch 260: training loss = 0.2478, validation loss = 0.1706, patience counter = 0.
# Epoch 261: training loss = 0.2440, validation loss = 0.1713, patience counter = 1.
# Epoch 262: training loss = 0.2358, validation loss = 0.1718, patience counter = 2.
# Epoch 263: training loss = 0.2408, validation loss = 0.1716, patience counter = 3.
# Epoch 264: training loss = 0.2409, validation loss = 0.1711, patience counter = 4.
# Epoch 265: training loss = 0.2454, validation loss = 0.1720, patience counter = 5.
# Epoch 266: training loss = 0.2379, validation loss = 0.1716, patience counter = 6.
# Epoch 267: training loss = 0.2423, validation loss = 0.1716, patience counter = 7.
# Epoch 268: training loss = 0.2434, validation loss = 0.1716, patience counter = 8.
# Epoch 269: training loss = 0.2408, validation loss = 0.1716, patience counter = 9.
# Epoch 270: training loss = 0.2491, validation loss = 0.1720, patience counter = 10.
# Epoch 271: training loss = 0.2431, validation loss = 0.1721, patience counter = 11.
# Epoch 272: training loss = 0.2378, validation loss = 0.1717, patience counter = 12.
# Epoch 273: training loss = 0.2398, validation loss = 0.1712, patience counter = 13.
# Epoch 274: training loss = 0.2419, validation loss = 0.1704, patience counter = 0.
# Epoch 275: training loss = 0.2456, validation loss = 0.1711, patience counter = 1.
# Epoch 276: training loss = 0.2432, validation loss = 0.1703, patience counter = 0.
# Epoch 277: training loss = 0.2422, validation loss = 0.1709, patience counter = 1.
# Epoch 278: training loss = 0.2390, validation loss = 0.1718, patience counter = 2.
# Epoch 279: training loss = 0.2403, validation loss = 0.1709, patience counter = 3.
# Epoch 280: training loss = 0.2515, validation loss = 0.1717, patience counter = 4.
# Epoch 281: training loss = 0.2461, validation loss = 0.1719, patience counter = 5.
# Epoch 282: training loss = 0.2458, validation loss = 0.1710, patience counter = 6.
# Epoch 283: training loss = 0.2396, validation loss = 0.1715, patience counter = 7.
# Epoch 284: training loss = 0.2460, validation loss = 0.1717, patience counter = 8.
# Epoch 285: training loss = 0.2388, validation loss = 0.1705, patience counter = 9.
# Epoch 286: training loss = 0.2456, validation loss = 0.1714, patience counter = 10.
# Epoch 287: training loss = 0.2405, validation loss = 0.1705, patience counter = 11.
# Epoch 288: training loss = 0.2405, validation loss = 0.1711, patience counter = 12.
# Epoch 289: training loss = 0.2467, validation loss = 0.1710, patience counter = 13.
# Epoch 290: training loss = 0.2393, validation loss = 0.1709, patience counter = 14.
# Epoch 291: training loss = 0.2395, validation loss = 0.1714, patience counter = 15.
# Epoch 292: training loss = 0.2489, validation loss = 0.1711, patience counter = 16.
# Epoch 293: training loss = 0.2394, validation loss = 0.1714, patience counter = 17.
# Epoch 294: training loss = 0.2484, validation loss = 0.1714, patience counter = 18.
# Epoch 295: training loss = 0.2400, validation loss = 0.1705, patience counter = 19.
# Epoch 296: training loss = 0.2400, validation loss = 0.1704, patience counter = 20.
# Epoch 297: training loss = 0.2376, validation loss = 0.1710, patience counter = 21.
# Epoch 298: training loss = 0.2425, validation loss = 0.1714, patience counter = 22.
# Epoch 299: training loss = 0.2406, validation loss = 0.1712, patience counter = 23.
# Epoch 300: training loss = 0.2420, validation loss = 0.1701, patience counter = 0.
# Epoch 301: training loss = 0.2471, validation loss = 0.1713, patience counter = 1.
# Epoch 302: training loss = 0.2407, validation loss = 0.1712, patience counter = 2.
# Epoch 303: training loss = 0.2408, validation loss = 0.1701, patience counter = 0.
# Epoch 304: training loss = 0.2392, validation loss = 0.1704, patience counter = 1.
# Epoch 305: training loss = 0.2468, validation loss = 0.1707, patience counter = 2.
# Epoch 306: training loss = 0.2413, validation loss = 0.1707, patience counter = 3.
# Epoch 307: training loss = 0.2391, validation loss = 0.1705, patience counter = 4.
# Epoch 308: training loss = 0.2407, validation loss = 0.1710, patience counter = 5.
# Epoch 309: training loss = 0.2404, validation loss = 0.1707, patience counter = 6.
# Epoch 310: training loss = 0.2438, validation loss = 0.1709, patience counter = 7.
# Epoch 311: training loss = 0.2462, validation loss = 0.1711, patience counter = 8.
# Epoch 312: training loss = 0.2481, validation loss = 0.1706, patience counter = 9.
# Epoch 313: training loss = 0.2376, validation loss = 0.1709, patience counter = 10.
# Epoch 314: training loss = 0.2420, validation loss = 0.1712, patience counter = 11.
# Epoch 315: training loss = 0.2373, validation loss = 0.1706, patience counter = 12.
# Epoch 316: training loss = 0.2411, validation loss = 0.1714, patience counter = 13.
# Epoch 317: training loss = 0.2367, validation loss = 0.1704, patience counter = 14.
# Epoch 318: training loss = 0.2387, validation loss = 0.1715, patience counter = 15.
# Epoch 319: training loss = 0.2448, validation loss = 0.1706, patience counter = 16.
# Epoch 320: training loss = 0.2454, validation loss = 0.1713, patience counter = 17.
# Epoch 321: training loss = 0.2440, validation loss = 0.1706, patience counter = 18.
# Epoch 322: training loss = 0.2479, validation loss = 0.1710, patience counter = 19.
# Epoch 323: training loss = 0.2412, validation loss = 0.1707, patience counter = 20.
# Epoch 324: training loss = 0.2419, validation loss = 0.1709, patience counter = 21.
# Epoch 325: training loss = 0.2363, validation loss = 0.1711, patience counter = 22.
# Epoch 326: training loss = 0.2460, validation loss = 0.1710, patience counter = 23.
# Epoch 327: training loss = 0.2374, validation loss = 0.1716, patience counter = 24.
# Epoch 328: training loss = 0.2445, validation loss = 0.1711, patience counter = 25.
# Epoch 329: training loss = 0.2418, validation loss = 0.1704, patience counter = 26.
# Epoch 330: training loss = 0.2409, validation loss = 0.1711, patience counter = 27.
# Epoch 331: training loss = 0.2414, validation loss = 0.1707, patience counter = 28.
# Epoch 332: training loss = 0.2420, validation loss = 0.1715, patience counter = 29.
# Epoch 333: training loss = 0.2402, validation loss = 0.1712, patience counter = 30.
# Epoch 334: training loss = 0.2422, validation loss = 0.1707, patience counter = 31.
# Epoch 335: training loss = 0.2446, validation loss = 0.1714, patience counter = 32.
# Epoch 336: training loss = 0.2409, validation loss = 0.1713, patience counter = 33.
# Epoch 337: training loss = 0.2396, validation loss = 0.1709, patience counter = 34.
# Epoch 338: training loss = 0.2399, validation loss = 0.1707, patience counter = 35.
# Epoch 339: training loss = 0.2423, validation loss = 0.1714, patience counter = 36.
# Epoch 340: training loss = 0.2406, validation loss = 0.1702, patience counter = 37.
# Epoch 341: training loss = 0.2384, validation loss = 0.1712, patience counter = 38.
# Epoch 342: training loss = 0.2457, validation loss = 0.1718, patience counter = 39.
# Epoch 343: training loss = 0.2458, validation loss = 0.1706, patience counter = 40.
# Epoch 344: training loss = 0.2392, validation loss = 0.1712, patience counter = 41.
# Epoch 345: training loss = 0.2414, validation loss = 0.1711, patience counter = 42.
# Epoch 346: training loss = 0.2409, validation loss = 0.1712, patience counter = 43.
# Epoch 347: training loss = 0.2409, validation loss = 0.1720, patience counter = 44.
# Epoch 348: training loss = 0.2472, validation loss = 0.1714, patience counter = 45.
# Epoch 349: training loss = 0.2369, validation loss = 0.1711, patience counter = 46.
# Epoch 350: training loss = 0.2489, validation loss = 0.1708, patience counter = 47.
# Epoch 351: training loss = 0.2409, validation loss = 0.1702, patience counter = 48.
# Epoch 352: training loss = 0.2473, validation loss = 0.1715, patience counter = 49.
# Training stopped at epoch 353. Restoring weights from epoch 303.
# C:\Users\alled\AppData\Local\Temp\ipykernel_9336\1853304693.py:110: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load('../data/artifacts/weights.p'))
# C:\Users\alled\AppData\Local\Temp\ipykernel_9336\797787205.py:37: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('../data/artifacts/weights.p'))
