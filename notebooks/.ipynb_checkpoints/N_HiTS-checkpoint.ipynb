# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import torch
from sklearn.preprocessing import StandardScaler
from typing import Tuple

# %%
dict_params = {'data': {'len_input': 100, 'delta': 1, 'horizon_forecast': 20, 'size_train': 0.8, 'size_valid': 0.2},
               'model': {'stack_1': {'kernel_size_pool': 16, 'expr_ratio_m1': 16}, 'stack_2': {'kernel_size_pool': 4, 'expr_ratio_m1': 4},
                         'stack_3': {'kernel_size_pool': 1, 'expr_ratio_m1': 1}, 'n_neur_hidden': 200, 'frac_dropout': 0.2, 'stride_maxpool': 1},
               'training': {'batch_size': 256, 'n_epochs': 500, 'patience': 50, 'min_delta_loss_perc': 0.01}}

# %%
class Block(torch.nn.Module):
    def __init__(self, kernel_size_pool: int, expr_ratio_m1: int, dict_params: dict, num_features: int) -> None:
        '''
        Block of the N-HiTS architecture.
        
        Args:
            kernel_size_pool: Kernel size of the MaxPool layer.
            expr_ratio_m1: Inverse of the expressiveness ratio; it should be greater than 1.
            dict_params: Dictionary containing the configuration settings.
            num_features: Number of features of the input series.
            
        Returns: None.
        '''
        super().__init__()
        #
        self.len_input = dict_params['data']['len_input']
        self.horizon_forecast = dict_params['data']['horizon_forecast']
        n_neur_hidden = dict_params['model']['n_neur_hidden']
        frac_dropout = dict_params['model']['frac_dropout']
        # dimension of theta_f
        self.dim_theta_f = int(np.ceil(self.horizon_forecast/expr_ratio_m1))
        # hidden layers of the FC stack
        self.max_pool = torch.nn.MaxPool1d(kernel_size = kernel_size_pool, stride = dict_params['model']['stride_maxpool'])
        self.dense_hid_1 = torch.nn.Linear(in_features = int(np.floor((self.len_input - kernel_size_pool)/dict_params['model']['stride_maxpool'] + 1)),
                                           out_features = n_neur_hidden)
        self.dense_hid_2 = torch.nn.Linear(in_features = n_neur_hidden, out_features = n_neur_hidden)
        self.relu = torch.nn.ReLU()
        self.dropout = torch.nn.Dropout(p = frac_dropout)
        self.batch_norm_1 = torch.nn.BatchNorm1d(n_neur_hidden)
        self.batch_norm_2 = torch.nn.BatchNorm1d(n_neur_hidden)
        # dense layer for producing the theta's
        self.dense_theta_b = torch.nn.Linear(in_features = n_neur_hidden, out_features = self.len_input, bias = False)
        self.dense_theta_f = torch.nn.Linear(in_features = n_neur_hidden, out_features = self.dim_theta_f, bias = False)
        
    def forward(self, x):
        y = self.max_pool(x)
        #
        y = self.dense_hid_1(y).transpose(1, 2)
        y = self.batch_norm_1(y).transpose(1, 2)
        y = self.relu(y)
        y = self.dropout(y)
        y = self.dense_hid_2(y).transpose(1, 2)
        y = self.batch_norm_2(y).transpose(1, 2)
        y = self.relu(y)
        y = self.dropout(y)
        # compute theta's
        theta_b = self.dense_theta_b(y)
        theta_f = self.dense_theta_f(y)
        # compute backcast
        x_hat = theta_b
        # compute forecast
        y_hat = torch.nn.functional.interpolate(input = theta_f, size = self.horizon_forecast)
        y_hat = y_hat[:, :1, :]
        #
        return x_hat, y_hat

class Stack(torch.nn.Module):
    def __init__(self, stack_number: int, dict_params: dict, num_features: int) -> None:
        '''
        Stack of the N-HiTS architecture.
        
        Args:
            stack_number: Integer indicating the block index in the stack, starting from 1.
            dict_params: Dictionary containing the configuration settings.
            num_features: Number of features of the input series.
            
        Returns: None
        '''
        super().__init__()
        stack_params = dict_params['model'][f'stack_{stack_number}']
        kernel_size_pool = stack_params['kernel_size_pool']
        expr_ratio_m1 = stack_params['expr_ratio_m1']
        #
        self.block = Block(kernel_size_pool = kernel_size_pool, expr_ratio_m1 = expr_ratio_m1, dict_params = dict_params,
                           num_features = num_features)
        
    def forward(self, x):
        x_hat, y = self.block(x)
        x = x - x_hat
        #
        x_hat = x
        y_hat = y
        return x_hat, y_hat

class NHiTS(torch.nn.Module):
    def __init__(self, dict_params: dict, num_features: int) -> None:
        '''
        N-HiTS architecture.
        
        Args:
            dict_params: Dictionary containing the configuration settings.
            num_features: Number of features of the input series.
            
        Returns: None
        '''
        super().__init__()
        #
        self.stack_1 = Stack(stack_number = 1, dict_params = dict_params, num_features = num_features)
        self.stack_2 = Stack(stack_number = 2, dict_params = dict_params, num_features = num_features)
        self.stack_3 = Stack(stack_number = 3, dict_params = dict_params, num_features = num_features)
        
    def forward(self, x):
        # first stack
        x_hat, y_hat_1 = self.stack_1(x)
        x = x - x_hat
        # second stack
        x_hat, y_hat_2 = self.stack_2(x)
        x = x - x_hat
        # third stack
        _, y_hat_3 = self.stack_3(x)
        #
        return y_hat_1, y_hat_2, y_hat_3

# %%
def train_test_splitting(df: pd.DataFrame, dict_params: dict) -> (pd.DataFrame, pd.DataFrame, pd.DataFrame):
    '''
    Function to split data in training, validation and test set.

    Args:
        df: Dataframe containing time series. The column representing the main series should be called `y`.
        dict_params: Dictionary containing information about data properties.

    Returns:
        df_train: Dataframe corresponding to training set.
        df_valid: Dataframe corresponding to validation set.
        df_test: Dataframe corresponding to test set.
    '''
    df_train = df.iloc[:int(df.shape[0]*dict_params['data']['size_train'])].copy().reset_index(drop = True)
    df_test = df.iloc[int(df.shape[0]*dict_params['data']['size_train']):].reset_index(drop = True).copy().reset_index(drop = True)
    df_valid = df_train.iloc[int(df_train.shape[0]*(1 - dict_params['data']['size_valid'])):].copy().reset_index(drop = True)
    df_train = df_train.iloc[:int(df_train.shape[0]*(1 - dict_params['data']['size_valid']))].copy().reset_index(drop = True)
    # rescale data
    scaler = StandardScaler().fit(df_train[['y']])
    df_train[['y']] = scaler.transform(df_train[['y']])
    df_valid[['y']] = scaler.transform(df_valid[['y']])
    df_test[['y']] = scaler.transform(df_test[['y']])
    #
    return df_train, df_valid, df_test, scaler

# %%
def get_x_y(df: pd.DataFrame, df_future: pd.DataFrame, dict_params: dict, test_set: bool = False,
            horizon_forecast: int = None) -> (torch.tensor, torch.tensor, np.array, np.array):
    '''
    Function obtain a tensor of regressors and one of target series.

    Args:
        df: Dataframe containing time series. The column representing the main series should be called `y`.
        df_future: Same as `df`, but corresponding to its future (e.g., `df_valid` could be the "future" of `df_train`).
        dict_params: Dictionary containing information about the model architecture.
        test_set: Whether `df` is the dataframe corresponding to test set.
        horizon_forecast: Length of the series to be predicted.

    Returns:
        x: Tensor representing regressors.
        y: Tensor representing target time series.
        date_x: Array containing the dates corresponding to the elements of `x`.
        date_y: Array containing the dates corresponding to the elements of `y`.
    '''
    dict_params = dict_params['data']
    #
    len_input = dict_params['len_input']
    delta = dict_params['delta']
    if (horizon_forecast is None) or (horizon_forecast >= len_input):
        horizon_forecast = len_input
    #
    df_present = df.copy()
    if test_set == False:
        df_future = pd.concat((df_present, df_future)).copy().shift(-len_input)
        df_future = df_future.iloc[:df_present.shape[0]].reset_index(drop = True)
    else:
        df_future = df_present.copy().shift(-len_input).dropna()
        df_present = df_present.iloc[:df_future.shape[0]]
    #
    x = np.array([df_present.loc[i: i + len_input - 1,
                                 [col for col in df_present.columns if col != 'date']].values for i in range(0, df_present.shape[0] - len_input, delta)])
    y = np.array([df_future.loc[i: i + horizon_forecast - 1, ['y']].values for i in range(0, df_future.shape[0] - horizon_forecast, delta)])
    date_x = np.array([df_present.loc[i: i + len_input - 1, 'date'].values for i in range(0, df_present.shape[0] - len_input, delta)])
    date_y = np.array([df_future.loc[i: i + horizon_forecast - 1, 'date'].values for i in range(0, df_future.shape[0] - horizon_forecast, delta)])
    #
    y = y[:x.shape[0]]
    date_y = date_y[:date_x.shape[0]]
    #
    x = torch.tensor(x.astype(np.float32)).transpose(1, 2)
    y = torch.tensor(y.astype(np.float32)).transpose(1, 2)
    #
    date_x = date_x.reshape(x.shape[0], 1, -1)
    date_y = date_y.reshape(y.shape[0], 1, -1)
    #
    return x, y, date_x, date_y

# %%
class CreateDataset(torch.utils.data.Dataset):
    def __init__(self, x, y):
        '''
        Class to create a PyTorch dataset.
        
        Args:
            x: Tensor representing regressors.
            y: Tensor representing target time series.
            
        Returns: None.
        '''
        self.x = x
        self.y = y
    
    def __len__(self):
        return self.x.shape[0]
        
    def __getitem__(self, idx):
        return self.x[idx], self.y[idx]

# %%
class TrainNHiTS:
    def __init__(self, model: torch.nn.Module, dict_params: dict, dataloader_train: torch.utils.data.DataLoader, dataloader_valid: torch.utils.data.DataLoader):
        '''
        Class to train the N-HiTS model.
        
        Args:
            model: PyTorch model.
            dict_params: Dictionary containing information about the model architecture.
            dataloader_train: Dataloader containing training data.
            dataloader_valid: Dataloader containing validation data.
            
        Returns: None.
        '''
        self.model = model
        self.dict_params = dict_params
        self.loss_func = torch.nn.MSELoss()
        self.optimizer = torch.optim.Adam(params = model.parameters())
        self.scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer = self.optimizer, factor = 0.5)
        self.dataloader_train = dataloader_train
        self.dataloader_valid = dataloader_valid

    def _model_on_batch(self, batch: tuple, training: bool, loss_epoch: float) -> float:
        '''
        Function to perform training on a single batch of data.
        
        Args:
            batch: Batch of data to use for training/evaluation.
            training: Whether to perform training (if not, evaluation is understood).
            loss_epoch: Loss of the current epoch.
            
        Returns:
            loss: Value of the loss function.
        '''
        if training == True:
            self.optimizer.zero_grad()
        #
        x, y_true = batch
        x = x.to('cpu')
        y_true = y_true.to('cpu')
        y_hat_1, y_hat_2, y_hat_3 = self.model(x)
        y_hat_1 = y_hat_1.to('cpu')
        y_hat_2 = y_hat_2.to('cpu')
        y_hat_3 = y_hat_3.to('cpu')
        #
        loss = self.loss_func(y_hat_1 + y_hat_2 + y_hat_3, y_true)
        #
        if training == True:
            loss.backward()
            self.optimizer.step()
        #
        return loss.item()

    def _train(self) -> float:
        '''
        Function to train the TCN model on a single epoch.
        
        Args: None.
            
        Returns:
            loss: Value of the training loss function per batch.
        '''
        self.model.train()
        loss_epoch = 0
        for batch in self.dataloader_train:
            loss_epoch += self._model_on_batch(batch = batch, training = True, loss_epoch = loss_epoch)
        return loss_epoch/len(self.dataloader_train)

    def _eval(self) -> float:
        '''
        Function to evaluate the TCN model on the validation set on a single epoch.
        
        Args: None.
            
        Returns:
            loss: Value of the validation loss function per batch.
        '''
        self.model.eval()
        loss_epoch = 0
        with torch.no_grad():
            for batch in self.dataloader_valid:
                loss_epoch += self._model_on_batch(batch = batch, training = False, loss_epoch = loss_epoch)
        return loss_epoch/len(self.dataloader_valid)

    def train_model(self) -> (torch.nn.Module, list, list):
        '''
        Function to train the TCN model.
        
        Args: None.
            
        Returns:
            model: Trained N-HiTS model.
            list_loss_train: List of training loss function across the epochs.
            list_loss_valid: List of validation loss function across the epochs.
        '''
        dict_params = self.dict_params
        n_epochs = dict_params['training']['n_epochs']
        list_loss_train, list_loss_valid = [], []
        counter_patience = 0
        for epoch in range(1, n_epochs + 1):
            loss_train = self._train()
            loss_valid = self._eval()
            #
            if (len(list_loss_valid) > 0) and (loss_valid >= np.min(list_loss_valid)*(1 - dict_params['training']['min_delta_loss_perc'])):
                counter_patience += 1
            if (len(list_loss_valid) == 0) or ((len(list_loss_valid) > 0) and (loss_valid < np.min(list_loss_valid))):
                counter_patience = 0
                torch.save(self.model.state_dict(), '../data/artifacts/weights.p')
            if counter_patience >= dict_params['training']['patience']:
                print(f'Training stopped at epoch {epoch}. Restoring weights from epoch {np.argmin(list_loss_valid) + 1}.')
                self.model.load_state_dict(torch.load('../data/artifacts/weights.p'))
                break
            #
            print(f'Epoch {epoch}: training loss = {loss_train:.4f}, validation loss = {loss_valid:.4f}, patience counter = {counter_patience}.')
            self.scheduler.step(loss_valid)
            #
            list_loss_train.append(loss_train)
            list_loss_valid.append(loss_valid)
        if epoch == n_epochs:
            self.model.load_state_dict(torch.load('../data/artifacts/weights.p'))
        return self.model, list_loss_train, list_loss_valid

# %%
def get_y_true_y_hat(model: torch.nn.Module, x: torch.tensor, y: torch.tensor, date_y: np.array,
                     scaler: sklearn.preprocessing.StandardScaler) -> (np.array, np.array, np.array):
    '''
    Function to get the real time series and its prediction.
    
    Args:
        model: Trained N-BEATS model.
        x: Tensor representing regressors.
        y: Tensor representing target time series.
        date_y: Array containing the dates corresponding to the elements of `y`.
        scaler: Scaled used to rescale data.
        
    Returns:
        y_true: Array containing the true values.
        y_hat_trend: Array containing the predicted trend.
        y_hat_seas: Array containing the predicted seasonality.
    '''
    list_date = []
    y_true = []
    y_hat_1, y_hat_2, y_hat_3 = [], [], []
    pred_1, pred_2, pred_3 = model(x)
    for i in range(np.unique(date_y).shape[0]):
        date = np.unique(date_y)[i]
        list_date.append(date)
        idx = np.where(date_y == date)
        y_true.append(y.numpy()[idx].mean())
        y_hat_1.append(pred_1.detach().numpy()[idx].mean())
        y_hat_2.append(pred_2.detach().numpy()[idx].mean())
        y_hat_3.append(pred_3.detach().numpy()[idx].mean())
    y_true = np.array(y_true)
    y_hat_1 = np.array(y_hat_1)
    y_hat_2 = np.array(y_hat_2)
    y_hat_3 = np.array(y_hat_3)
    # scale back
    y_true = scaler.inverse_transform(y_true.reshape(-1, 1)).ravel()
    y_hat_1 = scaler.inverse_transform(y_hat_1.reshape(-1, 1)).ravel()
    y_hat_2 = scaler.inverse_transform(y_hat_2.reshape(-1, 1)).ravel()
    y_hat_3 = scaler.inverse_transform(y_hat_3.reshape(-1, 1)).ravel()
    #
    return y_true, y_hat_1, y_hat_2, y_hat_3

# %%
def compute_mape(y_true: np.array, y_hat_1: np.array, y_hat_2: np.array, y_hat_3: np.array, scaler: sklearn.preprocessing.StandardScaler) -> float:
    '''
    Function to compute the MAPE.
    
    Args:
        y_true: Array containing the true values.
        y_hat_1: Array containing the first predicted component.
        y_hat_2: Array containing the second predicted component.
        y_hat_3: Array containing the third predicted component.
        scaler: Scaled used to rescale data.
        
    Returns:
        mape: MAPE computed from `y_true` and `y_hat`.
    '''
    y_hat = y_hat_1 + y_hat_2 + y_hat_3 - 2*scaler.mean_
    mape = np.mean(abs(y_true[y_true > 0] - y_hat[y_true > 0])/y_true[y_true > 0])
    return mape

# %%
df = pd.read_csv('../data/raw/train.csv', parse_dates = ['date'], index_col = 'id')
df = df.groupby(['date', 'family']).agg({'sales': 'sum'}).reset_index()
# add all dates
df_temp = []
for family in df['family'].unique():
    df_temp.append(pd.DataFrame({'date': pd.date_range(df['date'].min(), df['date'].max())}).merge(df[df['family'] == family],
                                                                                                on = 'date', how = 'left'))
    df_temp[-1]['family'] = family
    df_temp[-1]['sales'] = df_temp[-1]['sales'].ffill()
df = pd.concat(df_temp).reset_index(drop = True)
del df_temp
df = df.rename(columns = {'sales': 'y'})
# perform train-test splitting
df_train, df_valid, df_test, scaler = train_test_splitting(df = df[df['family'] == 'AUTOMOTIVE'].reset_index(drop = True).drop('family', axis = 1),
                                                        dict_params = dict_params)
#
horizon_forecast = dict_params['data']['horizon_forecast']
# training set data
x_train, y_train, date_x_train, date_y_train = get_x_y(df = df_train, df_future = df_valid, dict_params = dict_params,
                                                       test_set = False, horizon_forecast = horizon_forecast)
# validation set data
x_valid, y_valid, date_x_valid, date_y_valid = get_x_y(df = df_valid, df_future = df_test, dict_params = dict_params,
                                                       test_set = False, horizon_forecast = horizon_forecast)
# test set data
x_test, y_test, date_x_test, date_y_test = get_x_y(df = df_test, df_future = None, dict_params = dict_params, test_set = True,
                                                   horizon_forecast = horizon_forecast)
# create datasets and dataloader
dataset_train = CreateDataset(x = x_train, y = y_train)
dataset_valid = CreateDataset(x = x_valid, y = y_valid)
dataloader_train = torch.utils.data.DataLoader(dataset_train, batch_size = dict_params['training']['batch_size'], shuffle = True)
dataloader_valid = torch.utils.data.DataLoader(dataset_valid, batch_size = dict_params['training']['batch_size'], shuffle = False)
# train model
model = NHiTS(dict_params = dict_params, num_features = x_train.shape[2])
model, list_loss_train, list_loss_valid = TrainNHiTS(model = model, dict_params = dict_params, dataloader_train = dataloader_train, dataloader_valid = dataloader_train).train_model()
# evaluate results
model = NHiTS(dict_params = dict_params, num_features = x_train.shape[2])
model.load_state_dict(torch.load('../data/artifacts/weights.p'))
model.eval()
# get time series and the corresponding predictions
y_true_train, y_hat_1_train, y_hat_2_train, y_hat_3_train = get_y_true_y_hat(model = model, x = x_train, y = y_train, date_y = date_y_train, scaler = scaler)
y_true_valid, y_hat_1_valid, y_hat_2_valid, y_hat_3_valid = get_y_true_y_hat(model = model, x = x_valid, y = y_valid, date_y = date_y_valid, scaler = scaler)
y_true_test, y_hat_1_test, y_hat_2_test, y_hat_3_test = get_y_true_y_hat(model = model, x = x_test, y = y_test, date_y = date_y_test, scaler = scaler)
# compute mape on training, validation and test set
mape_train = compute_mape(y_true = y_true_train, y_hat_1 = y_hat_1_train, y_hat_2 = y_hat_2_train, y_hat_3 = y_hat_3_train, scaler = scaler)
mape_valid = compute_mape(y_true = y_true_valid, y_hat_1 = y_hat_1_valid, y_hat_2 = y_hat_2_valid, y_hat_3 = y_hat_3_valid, scaler = scaler)
mape_test = compute_mape(y_true = y_true_test, y_hat_1 = y_hat_1_test, y_hat_2 = y_hat_2_test, y_hat_3 = y_hat_3_test, scaler = scaler)
#
plt.figure(figsize = [10, 6])
plt.plot(np.unique(date_y_test), y_true_test, label = 'True', color = 'r')
plt.plot(np.unique(date_y_test), y_hat_1_test + y_hat_2_test + y_hat_3_test - 2*scaler.mean_, label = 'Predicted', color = 'b')
plt.plot(np.unique(date_y_test), y_hat_1_test, label = 'First predicted component', color = 'b', ls = '--')
plt.plot(np.unique(date_y_test), y_hat_2_test - scaler.mean_, label = 'Second predicted component', color = 'b', ls = '-.')
plt.plot(np.unique(date_y_test), y_hat_3_test - scaler.mean_, label = 'Third predicted component', color = 'b', ls = ':')
plt.xlabel('Date', fontsize = 16)
plt.ylabel('Sales', fontsize = 16)
plt.xticks(rotation = 45)
plt.legend()
plt.savefig('../docs/figures_for_readme/result', bbox_inches = 'tight')
#
plt.figure(figsize = [10, 6])
plt.plot(list_loss_train, c = 'r', label = 'Training')
plt.plot(list_loss_valid, c = 'b', label = 'Validation')
plt.xlabel('Epoch', fontsize = 16)
plt.ylabel('Loss', fontsize = 16)
plt.legend()
plt.savefig('../docs/figures_for_readme/loss', bbox_inches = 'tight')
plt.show()
# Out:
# Epoch 1: training loss = 1.3414, validation loss = 0.9704, patience counter = 0.
# Epoch 2: training loss = 1.1589, validation loss = 0.9424, patience counter = 0.
# Epoch 3: training loss = 1.0503, validation loss = 0.9026, patience counter = 0.
# Epoch 4: training loss = 1.0110, validation loss = 0.8771, patience counter = 0.
# Epoch 5: training loss = 0.9869, validation loss = 0.8591, patience counter = 0.
# Epoch 6: training loss = 0.9667, validation loss = 0.8261, patience counter = 0.
# Epoch 7: training loss = 0.9328, validation loss = 0.8147, patience counter = 0.
# Epoch 8: training loss = 0.9171, validation loss = 0.8102, patience counter = 0.
# Epoch 9: training loss = 0.9121, validation loss = 0.7860, patience counter = 0.
# Epoch 10: training loss = 0.8891, validation loss = 0.7724, patience counter = 0.
# Epoch 11: training loss = 0.8795, validation loss = 0.7699, patience counter = 0.
# Epoch 12: training loss = 0.8669, validation loss = 0.7599, patience counter = 0.
# Epoch 13: training loss = 0.8432, validation loss = 0.7350, patience counter = 0.
# Epoch 14: training loss = 0.8360, validation loss = 0.7246, patience counter = 0.
# Epoch 15: training loss = 0.8279, validation loss = 0.7093, patience counter = 0.
# Epoch 16: training loss = 0.8004, validation loss = 0.6826, patience counter = 0.
# Epoch 17: training loss = 0.7969, validation loss = 0.6936, patience counter = 1.
# Epoch 18: training loss = 0.7711, validation loss = 0.6487, patience counter = 0.
# Epoch 19: training loss = 0.7499, validation loss = 0.6162, patience counter = 0.
# Epoch 20: training loss = 0.7131, validation loss = 0.6157, patience counter = 0.
# Epoch 21: training loss = 0.6960, validation loss = 0.5893, patience counter = 0.
# Epoch 22: training loss = 0.6795, validation loss = 0.5445, patience counter = 0.
# Epoch 23: training loss = 0.6437, validation loss = 0.5145, patience counter = 0.
# Epoch 24: training loss = 0.6100, validation loss = 0.4945, patience counter = 0.
# Epoch 25: training loss = 0.5911, validation loss = 0.4831, patience counter = 0.
# Epoch 26: training loss = 0.5737, validation loss = 0.4306, patience counter = 0.
# Epoch 27: training loss = 0.5416, validation loss = 0.4358, patience counter = 1.
# Epoch 28: training loss = 0.5249, validation loss = 0.5497, patience counter = 2.
# Epoch 29: training loss = 0.4982, validation loss = 0.4457, patience counter = 3.
# Epoch 30: training loss = 0.4884, validation loss = 0.4374, patience counter = 4.
# Epoch 31: training loss = 0.4862, validation loss = 0.3608, patience counter = 0.
# Epoch 32: training loss = 0.4628, validation loss = 0.3463, patience counter = 0.
# Epoch 33: training loss = 0.4608, validation loss = 0.4164, patience counter = 1.
# Epoch 34: training loss = 0.4483, validation loss = 0.3497, patience counter = 2.
# Epoch 35: training loss = 0.4412, validation loss = 0.4169, patience counter = 3.
# Epoch 36: training loss = 0.4325, validation loss = 0.3564, patience counter = 4.
# Epoch 37: training loss = 0.4141, validation loss = 0.4657, patience counter = 5.
# Epoch 38: training loss = 0.4094, validation loss = 0.3199, patience counter = 0.
# Epoch 39: training loss = 0.4152, validation loss = 0.3388, patience counter = 1.
# Epoch 40: training loss = 0.3975, validation loss = 0.2891, patience counter = 0.
# Epoch 41: training loss = 0.3927, validation loss = 0.3588, patience counter = 1.
# Epoch 42: training loss = 0.3851, validation loss = 0.2775, patience counter = 0.
# Epoch 43: training loss = 0.3885, validation loss = 0.2932, patience counter = 1.
# Epoch 44: training loss = 0.3747, validation loss = 0.2836, patience counter = 2.
# Epoch 45: training loss = 0.3754, validation loss = 0.2817, patience counter = 3.
# Epoch 46: training loss = 0.3711, validation loss = 0.2744, patience counter = 0.
# Epoch 47: training loss = 0.3837, validation loss = 0.2582, patience counter = 0.
# Epoch 48: training loss = 0.3630, validation loss = 0.2680, patience counter = 1.
# Epoch 49: training loss = 0.3547, validation loss = 0.2586, patience counter = 2.
# Epoch 50: training loss = 0.3618, validation loss = 0.2904, patience counter = 3.
# Epoch 51: training loss = 0.3544, validation loss = 0.2598, patience counter = 4.
# Epoch 52: training loss = 0.3577, validation loss = 0.2703, patience counter = 5.
# Epoch 53: training loss = 0.3494, validation loss = 0.2726, patience counter = 6.
# Epoch 54: training loss = 0.3565, validation loss = 0.2823, patience counter = 7.
# Epoch 55: training loss = 0.3469, validation loss = 0.2620, patience counter = 8.
# Epoch 56: training loss = 0.3439, validation loss = 0.2537, patience counter = 0.
# Epoch 57: training loss = 0.3449, validation loss = 0.2764, patience counter = 1.
# Epoch 58: training loss = 0.3451, validation loss = 0.2915, patience counter = 2.
# Epoch 59: training loss = 0.3390, validation loss = 0.2618, patience counter = 3.
# Epoch 60: training loss = 0.3409, validation loss = 0.2791, patience counter = 4.
# Epoch 61: training loss = 0.3396, validation loss = 0.2992, patience counter = 5.
# Epoch 62: training loss = 0.3362, validation loss = 0.2355, patience counter = 0.
# Epoch 63: training loss = 0.3291, validation loss = 0.2436, patience counter = 1.
# Epoch 64: training loss = 0.3351, validation loss = 0.2308, patience counter = 0.
# Epoch 65: training loss = 0.3256, validation loss = 0.2280, patience counter = 0.
# Epoch 66: training loss = 0.3165, validation loss = 0.2363, patience counter = 1.
# Epoch 67: training loss = 0.3236, validation loss = 0.2717, patience counter = 2.
# Epoch 68: training loss = 0.3229, validation loss = 0.2386, patience counter = 3.
# Epoch 69: training loss = 0.3205, validation loss = 0.2563, patience counter = 4.
# Epoch 70: training loss = 0.3214, validation loss = 0.2825, patience counter = 5.
# Epoch 71: training loss = 0.3153, validation loss = 0.2402, patience counter = 6.
# Epoch 72: training loss = 0.3160, validation loss = 0.2389, patience counter = 7.
# Epoch 73: training loss = 0.3143, validation loss = 0.2308, patience counter = 8.
# Epoch 74: training loss = 0.3062, validation loss = 0.2292, patience counter = 9.
# Epoch 75: training loss = 0.3052, validation loss = 0.2459, patience counter = 10.
# Epoch 76: training loss = 0.3140, validation loss = 0.2333, patience counter = 11.
# Epoch 77: training loss = 0.2975, validation loss = 0.2127, patience counter = 0.
# Epoch 78: training loss = 0.2911, validation loss = 0.2040, patience counter = 0.
# Epoch 79: training loss = 0.2936, validation loss = 0.2059, patience counter = 1.
# Epoch 80: training loss = 0.2954, validation loss = 0.2046, patience counter = 2.
# Epoch 81: training loss = 0.2937, validation loss = 0.2075, patience counter = 3.
# Epoch 82: training loss = 0.2970, validation loss = 0.2061, patience counter = 4.
# Epoch 83: training loss = 0.3043, validation loss = 0.2085, patience counter = 5.
# Epoch 84: training loss = 0.2872, validation loss = 0.2140, patience counter = 6.
# Epoch 85: training loss = 0.2974, validation loss = 0.2016, patience counter = 0.
# Epoch 86: training loss = 0.2902, validation loss = 0.2019, patience counter = 1.
# Epoch 87: training loss = 0.2980, validation loss = 0.2303, patience counter = 2.
# Epoch 88: training loss = 0.2864, validation loss = 0.2062, patience counter = 3.
# Epoch 89: training loss = 0.2912, validation loss = 0.2103, patience counter = 4.
# Epoch 90: training loss = 0.2899, validation loss = 0.2169, patience counter = 5.
# Epoch 91: training loss = 0.2875, validation loss = 0.2024, patience counter = 6.
# Epoch 92: training loss = 0.2858, validation loss = 0.2008, patience counter = 0.
# Epoch 93: training loss = 0.2852, validation loss = 0.2091, patience counter = 1.
# Epoch 94: training loss = 0.2829, validation loss = 0.2179, patience counter = 2.
# Epoch 95: training loss = 0.2894, validation loss = 0.2026, patience counter = 3.
# Epoch 96: training loss = 0.2787, validation loss = 0.2024, patience counter = 4.
# Epoch 97: training loss = 0.2850, validation loss = 0.2004, patience counter = 0.
# Epoch 98: training loss = 0.2796, validation loss = 0.2105, patience counter = 1.
# Epoch 99: training loss = 0.2807, validation loss = 0.2030, patience counter = 2.
# Epoch 100: training loss = 0.2851, validation loss = 0.1956, patience counter = 0.
# Epoch 101: training loss = 0.2843, validation loss = 0.2126, patience counter = 1.
# Epoch 102: training loss = 0.2779, validation loss = 0.1967, patience counter = 2.
# Epoch 103: training loss = 0.2789, validation loss = 0.1994, patience counter = 3.
# Epoch 104: training loss = 0.2697, validation loss = 0.1968, patience counter = 4.
# Epoch 105: training loss = 0.2852, validation loss = 0.1954, patience counter = 0.
# Epoch 106: training loss = 0.2836, validation loss = 0.1932, patience counter = 0.
# Epoch 107: training loss = 0.2773, validation loss = 0.1928, patience counter = 0.
# Epoch 108: training loss = 0.2776, validation loss = 0.1954, patience counter = 1.
# Epoch 109: training loss = 0.2728, validation loss = 0.1944, patience counter = 2.
# Epoch 110: training loss = 0.2729, validation loss = 0.1923, patience counter = 0.
# Epoch 111: training loss = 0.2680, validation loss = 0.1968, patience counter = 1.
# Epoch 112: training loss = 0.2764, validation loss = 0.1959, patience counter = 2.
# Epoch 113: training loss = 0.2828, validation loss = 0.1932, patience counter = 3.
# Epoch 114: training loss = 0.2721, validation loss = 0.2029, patience counter = 4.
# Epoch 115: training loss = 0.2844, validation loss = 0.1975, patience counter = 5.
# Epoch 116: training loss = 0.2699, validation loss = 0.1941, patience counter = 6.
# Epoch 117: training loss = 0.2701, validation loss = 0.1934, patience counter = 7.
# Epoch 118: training loss = 0.2798, validation loss = 0.1975, patience counter = 8.
# Epoch 119: training loss = 0.2756, validation loss = 0.1988, patience counter = 9.
# Epoch 120: training loss = 0.2747, validation loss = 0.1930, patience counter = 10.
# Epoch 121: training loss = 0.2679, validation loss = 0.1924, patience counter = 11.
# Epoch 122: training loss = 0.2725, validation loss = 0.1873, patience counter = 0.
# Epoch 123: training loss = 0.2651, validation loss = 0.1914, patience counter = 1.
# Epoch 124: training loss = 0.2667, validation loss = 0.1857, patience counter = 0.
# Epoch 125: training loss = 0.2614, validation loss = 0.1890, patience counter = 1.
# Epoch 126: training loss = 0.2638, validation loss = 0.1858, patience counter = 2.
# Epoch 127: training loss = 0.2633, validation loss = 0.1888, patience counter = 3.
# Epoch 128: training loss = 0.2664, validation loss = 0.1853, patience counter = 0.
# Epoch 129: training loss = 0.2624, validation loss = 0.1845, patience counter = 0.
# Epoch 130: training loss = 0.2754, validation loss = 0.1824, patience counter = 0.
# Epoch 131: training loss = 0.2671, validation loss = 0.1840, patience counter = 1.
# Epoch 132: training loss = 0.2663, validation loss = 0.1828, patience counter = 2.
# Epoch 133: training loss = 0.2652, validation loss = 0.1840, patience counter = 3.
# Epoch 134: training loss = 0.2663, validation loss = 0.1891, patience counter = 4.
# Epoch 135: training loss = 0.2692, validation loss = 0.1874, patience counter = 5.
# Epoch 136: training loss = 0.2609, validation loss = 0.1870, patience counter = 6.
# Epoch 137: training loss = 0.2630, validation loss = 0.1830, patience counter = 7.
# Epoch 138: training loss = 0.2629, validation loss = 0.1842, patience counter = 8.
# Epoch 139: training loss = 0.2667, validation loss = 0.1881, patience counter = 9.
# Epoch 140: training loss = 0.2637, validation loss = 0.1833, patience counter = 10.
# Epoch 141: training loss = 0.2628, validation loss = 0.1854, patience counter = 11.
# Epoch 142: training loss = 0.2629, validation loss = 0.1824, patience counter = 0.
# Epoch 143: training loss = 0.2623, validation loss = 0.1843, patience counter = 1.
# Epoch 144: training loss = 0.2600, validation loss = 0.1829, patience counter = 2.
# Epoch 145: training loss = 0.2618, validation loss = 0.1799, patience counter = 0.
# Epoch 146: training loss = 0.2579, validation loss = 0.1819, patience counter = 1.
# Epoch 147: training loss = 0.2562, validation loss = 0.1804, patience counter = 2.
# Epoch 148: training loss = 0.2528, validation loss = 0.1790, patience counter = 0.
# Epoch 149: training loss = 0.2571, validation loss = 0.1800, patience counter = 1.
# Epoch 150: training loss = 0.2585, validation loss = 0.1792, patience counter = 2.
# Epoch 151: training loss = 0.2678, validation loss = 0.1785, patience counter = 0.
# Epoch 152: training loss = 0.2593, validation loss = 0.1792, patience counter = 1.
# Epoch 153: training loss = 0.2629, validation loss = 0.1793, patience counter = 2.
# Epoch 154: training loss = 0.2547, validation loss = 0.1780, patience counter = 0.
# Epoch 155: training loss = 0.2578, validation loss = 0.1784, patience counter = 1.
# Epoch 156: training loss = 0.2588, validation loss = 0.1785, patience counter = 2.
# Epoch 157: training loss = 0.2561, validation loss = 0.1775, patience counter = 0.
# Epoch 158: training loss = 0.2589, validation loss = 0.1789, patience counter = 1.
# Epoch 159: training loss = 0.2585, validation loss = 0.1796, patience counter = 2.
# Epoch 160: training loss = 0.2568, validation loss = 0.1784, patience counter = 3.
# Epoch 161: training loss = 0.2574, validation loss = 0.1794, patience counter = 4.
# Epoch 162: training loss = 0.2584, validation loss = 0.1807, patience counter = 5.
# Epoch 163: training loss = 0.2558, validation loss = 0.1795, patience counter = 6.
# Epoch 164: training loss = 0.2595, validation loss = 0.1782, patience counter = 7.
# Epoch 165: training loss = 0.2659, validation loss = 0.1787, patience counter = 8.
# Epoch 166: training loss = 0.2543, validation loss = 0.1794, patience counter = 9.
# Epoch 167: training loss = 0.2595, validation loss = 0.1771, patience counter = 0.
# Epoch 168: training loss = 0.2538, validation loss = 0.1779, patience counter = 1.
# Epoch 169: training loss = 0.2542, validation loss = 0.1773, patience counter = 2.
# Epoch 170: training loss = 0.2617, validation loss = 0.1773, patience counter = 3.
# Epoch 171: training loss = 0.2517, validation loss = 0.1781, patience counter = 4.
# Epoch 172: training loss = 0.2597, validation loss = 0.1794, patience counter = 5.
# Epoch 173: training loss = 0.2541, validation loss = 0.1786, patience counter = 6.
# Epoch 174: training loss = 0.2582, validation loss = 0.1779, patience counter = 7.
# Epoch 175: training loss = 0.2535, validation loss = 0.1780, patience counter = 8.
# Epoch 176: training loss = 0.2549, validation loss = 0.1780, patience counter = 9.
# Epoch 177: training loss = 0.2554, validation loss = 0.1786, patience counter = 10.
# Epoch 178: training loss = 0.2523, validation loss = 0.1778, patience counter = 11.
# Epoch 179: training loss = 0.2567, validation loss = 0.1786, patience counter = 12.
# Epoch 180: training loss = 0.2488, validation loss = 0.1772, patience counter = 13.
# Epoch 181: training loss = 0.2486, validation loss = 0.1776, patience counter = 14.
# Epoch 182: training loss = 0.2542, validation loss = 0.1763, patience counter = 0.
# Epoch 183: training loss = 0.2569, validation loss = 0.1767, patience counter = 1.
# Epoch 184: training loss = 0.2555, validation loss = 0.1763, patience counter = 2.
# Epoch 185: training loss = 0.2542, validation loss = 0.1758, patience counter = 0.
# Epoch 186: training loss = 0.2536, validation loss = 0.1761, patience counter = 1.
# Epoch 187: training loss = 0.2561, validation loss = 0.1750, patience counter = 0.
# Epoch 188: training loss = 0.2469, validation loss = 0.1756, patience counter = 1.
# Epoch 189: training loss = 0.2516, validation loss = 0.1758, patience counter = 2.
# Epoch 190: training loss = 0.2489, validation loss = 0.1759, patience counter = 3.
# Epoch 191: training loss = 0.2583, validation loss = 0.1760, patience counter = 4.
# Epoch 192: training loss = 0.2505, validation loss = 0.1757, patience counter = 5.
# Epoch 193: training loss = 0.2503, validation loss = 0.1759, patience counter = 6.
# Epoch 194: training loss = 0.2547, validation loss = 0.1757, patience counter = 7.
# Epoch 195: training loss = 0.2510, validation loss = 0.1756, patience counter = 8.
# Epoch 196: training loss = 0.2601, validation loss = 0.1765, patience counter = 9.
# Epoch 197: training loss = 0.2518, validation loss = 0.1750, patience counter = 0.
# Epoch 198: training loss = 0.2512, validation loss = 0.1766, patience counter = 1.
# Epoch 199: training loss = 0.2558, validation loss = 0.1764, patience counter = 2.
# Epoch 200: training loss = 0.2580, validation loss = 0.1758, patience counter = 3.
# Epoch 201: training loss = 0.2511, validation loss = 0.1755, patience counter = 4.
# Epoch 202: training loss = 0.2545, validation loss = 0.1752, patience counter = 5.
# Epoch 203: training loss = 0.2597, validation loss = 0.1752, patience counter = 6.
# Epoch 204: training loss = 0.2454, validation loss = 0.1748, patience counter = 0.
# Epoch 205: training loss = 0.2604, validation loss = 0.1757, patience counter = 1.
# Epoch 206: training loss = 0.2578, validation loss = 0.1747, patience counter = 0.
# Epoch 207: training loss = 0.2479, validation loss = 0.1749, patience counter = 1.
# Epoch 208: training loss = 0.2613, validation loss = 0.1751, patience counter = 2.
# Epoch 209: training loss = 0.2502, validation loss = 0.1748, patience counter = 3.
# Epoch 210: training loss = 0.2461, validation loss = 0.1742, patience counter = 0.
# Epoch 211: training loss = 0.2576, validation loss = 0.1753, patience counter = 1.
# Epoch 212: training loss = 0.2485, validation loss = 0.1750, patience counter = 2.
# Epoch 213: training loss = 0.2499, validation loss = 0.1750, patience counter = 3.
# Epoch 214: training loss = 0.2489, validation loss = 0.1751, patience counter = 4.
# Epoch 215: training loss = 0.2513, validation loss = 0.1744, patience counter = 5.
# Epoch 216: training loss = 0.2527, validation loss = 0.1745, patience counter = 6.
# Epoch 217: training loss = 0.2508, validation loss = 0.1748, patience counter = 7.
# Epoch 218: training loss = 0.2539, validation loss = 0.1747, patience counter = 8.
# Epoch 219: training loss = 0.2562, validation loss = 0.1741, patience counter = 0.
# Epoch 220: training loss = 0.2466, validation loss = 0.1737, patience counter = 0.
# Epoch 221: training loss = 0.2450, validation loss = 0.1747, patience counter = 1.
# Epoch 222: training loss = 0.2525, validation loss = 0.1741, patience counter = 2.
# Epoch 223: training loss = 0.2523, validation loss = 0.1743, patience counter = 3.
# Epoch 224: training loss = 0.2518, validation loss = 0.1738, patience counter = 4.
# Epoch 225: training loss = 0.2532, validation loss = 0.1742, patience counter = 5.
# Epoch 226: training loss = 0.2491, validation loss = 0.1745, patience counter = 6.
# Epoch 227: training loss = 0.2496, validation loss = 0.1746, patience counter = 7.
# Epoch 228: training loss = 0.2575, validation loss = 0.1746, patience counter = 8.
# Epoch 229: training loss = 0.2537, validation loss = 0.1743, patience counter = 9.
# Epoch 230: training loss = 0.2544, validation loss = 0.1744, patience counter = 10.
# Epoch 231: training loss = 0.2535, validation loss = 0.1737, patience counter = 11.
# Epoch 232: training loss = 0.2558, validation loss = 0.1737, patience counter = 0.
# Epoch 233: training loss = 0.2513, validation loss = 0.1735, patience counter = 0.
# Epoch 234: training loss = 0.2479, validation loss = 0.1741, patience counter = 1.
# Epoch 235: training loss = 0.2536, validation loss = 0.1740, patience counter = 2.
# Epoch 236: training loss = 0.2456, validation loss = 0.1740, patience counter = 3.
# Epoch 237: training loss = 0.2468, validation loss = 0.1740, patience counter = 4.
# Epoch 238: training loss = 0.2495, validation loss = 0.1739, patience counter = 5.
# Epoch 239: training loss = 0.2481, validation loss = 0.1743, patience counter = 6.
# Epoch 240: training loss = 0.2486, validation loss = 0.1741, patience counter = 7.
# Epoch 241: training loss = 0.2483, validation loss = 0.1746, patience counter = 8.
# Epoch 242: training loss = 0.2537, validation loss = 0.1741, patience counter = 9.
# Epoch 243: training loss = 0.2501, validation loss = 0.1739, patience counter = 10.
# Epoch 244: training loss = 0.2476, validation loss = 0.1739, patience counter = 11.
# Epoch 245: training loss = 0.2530, validation loss = 0.1745, patience counter = 12.
# Epoch 246: training loss = 0.2527, validation loss = 0.1738, patience counter = 13.
# Epoch 247: training loss = 0.2504, validation loss = 0.1743, patience counter = 14.
# Epoch 248: training loss = 0.2541, validation loss = 0.1742, patience counter = 15.
# Epoch 249: training loss = 0.2539, validation loss = 0.1740, patience counter = 16.
# Epoch 250: training loss = 0.2522, validation loss = 0.1745, patience counter = 17.
# Epoch 251: training loss = 0.2455, validation loss = 0.1735, patience counter = 18.
# Epoch 252: training loss = 0.2478, validation loss = 0.1741, patience counter = 19.
# Epoch 253: training loss = 0.2506, validation loss = 0.1742, patience counter = 20.
# Epoch 254: training loss = 0.2512, validation loss = 0.1748, patience counter = 21.
# Epoch 255: training loss = 0.2498, validation loss = 0.1743, patience counter = 22.
# Epoch 256: training loss = 0.2510, validation loss = 0.1739, patience counter = 23.
# Epoch 257: training loss = 0.2473, validation loss = 0.1741, patience counter = 24.
# Epoch 258: training loss = 0.2488, validation loss = 0.1741, patience counter = 25.
# Epoch 259: training loss = 0.2468, validation loss = 0.1745, patience counter = 26.
# Epoch 260: training loss = 0.2514, validation loss = 0.1741, patience counter = 27.
# Epoch 261: training loss = 0.2480, validation loss = 0.1737, patience counter = 28.
# Epoch 262: training loss = 0.2530, validation loss = 0.1736, patience counter = 29.
# Epoch 263: training loss = 0.2574, validation loss = 0.1736, patience counter = 30.
# Epoch 264: training loss = 0.2550, validation loss = 0.1738, patience counter = 31.
# Epoch 265: training loss = 0.2556, validation loss = 0.1733, patience counter = 0.
# Epoch 266: training loss = 0.2480, validation loss = 0.1735, patience counter = 1.
# Epoch 267: training loss = 0.2545, validation loss = 0.1743, patience counter = 2.
# Epoch 268: training loss = 0.2467, validation loss = 0.1740, patience counter = 3.
# Epoch 269: training loss = 0.2500, validation loss = 0.1743, patience counter = 4.
# Epoch 270: training loss = 0.2500, validation loss = 0.1734, patience counter = 5.
# Epoch 271: training loss = 0.2507, validation loss = 0.1730, patience counter = 0.
# Epoch 272: training loss = 0.2514, validation loss = 0.1739, patience counter = 1.
# Epoch 273: training loss = 0.2516, validation loss = 0.1738, patience counter = 2.
# Epoch 274: training loss = 0.2593, validation loss = 0.1744, patience counter = 3.
# Epoch 275: training loss = 0.2449, validation loss = 0.1736, patience counter = 4.
# Epoch 276: training loss = 0.2596, validation loss = 0.1739, patience counter = 5.
# Epoch 277: training loss = 0.2552, validation loss = 0.1735, patience counter = 6.
# Epoch 278: training loss = 0.2462, validation loss = 0.1735, patience counter = 7.
# Epoch 279: training loss = 0.2471, validation loss = 0.1736, patience counter = 8.
# Epoch 280: training loss = 0.2503, validation loss = 0.1745, patience counter = 9.
# Epoch 281: training loss = 0.2500, validation loss = 0.1740, patience counter = 10.
# Epoch 282: training loss = 0.2436, validation loss = 0.1749, patience counter = 11.
# Epoch 283: training loss = 0.2506, validation loss = 0.1747, patience counter = 12.
# Epoch 284: training loss = 0.2488, validation loss = 0.1739, patience counter = 13.
# Epoch 285: training loss = 0.2532, validation loss = 0.1743, patience counter = 14.
# Epoch 286: training loss = 0.2508, validation loss = 0.1739, patience counter = 15.
# Epoch 287: training loss = 0.2522, validation loss = 0.1737, patience counter = 16.
# Epoch 288: training loss = 0.2568, validation loss = 0.1736, patience counter = 17.
# Epoch 289: training loss = 0.2454, validation loss = 0.1748, patience counter = 18.
# Epoch 290: training loss = 0.2492, validation loss = 0.1744, patience counter = 19.
# Epoch 291: training loss = 0.2502, validation loss = 0.1746, patience counter = 20.
# Epoch 292: training loss = 0.2477, validation loss = 0.1736, patience counter = 21.
# Epoch 293: training loss = 0.2464, validation loss = 0.1743, patience counter = 22.
# Epoch 294: training loss = 0.2575, validation loss = 0.1735, patience counter = 23.
# Epoch 295: training loss = 0.2471, validation loss = 0.1736, patience counter = 24.
# Epoch 296: training loss = 0.2508, validation loss = 0.1739, patience counter = 25.
# Epoch 297: training loss = 0.2496, validation loss = 0.1737, patience counter = 26.
# Epoch 298: training loss = 0.2461, validation loss = 0.1730, patience counter = 0.
# Epoch 299: training loss = 0.2432, validation loss = 0.1741, patience counter = 1.
# Epoch 300: training loss = 0.2468, validation loss = 0.1744, patience counter = 2.
# Epoch 301: training loss = 0.2497, validation loss = 0.1735, patience counter = 3.
# Epoch 302: training loss = 0.2493, validation loss = 0.1738, patience counter = 4.
# Epoch 303: training loss = 0.2495, validation loss = 0.1734, patience counter = 5.
# Epoch 304: training loss = 0.2528, validation loss = 0.1736, patience counter = 6.
# Epoch 305: training loss = 0.2592, validation loss = 0.1738, patience counter = 7.
# Epoch 306: training loss = 0.2434, validation loss = 0.1740, patience counter = 8.
# Epoch 307: training loss = 0.2459, validation loss = 0.1736, patience counter = 9.
# Epoch 308: training loss = 0.2495, validation loss = 0.1733, patience counter = 10.
# Epoch 309: training loss = 0.2544, validation loss = 0.1740, patience counter = 11.
# Epoch 310: training loss = 0.2438, validation loss = 0.1734, patience counter = 12.
# Epoch 311: training loss = 0.2528, validation loss = 0.1737, patience counter = 13.
# Epoch 312: training loss = 0.2477, validation loss = 0.1737, patience counter = 14.
# Epoch 313: training loss = 0.2475, validation loss = 0.1731, patience counter = 15.
# Epoch 314: training loss = 0.2512, validation loss = 0.1735, patience counter = 16.
# Epoch 315: training loss = 0.2441, validation loss = 0.1742, patience counter = 17.
# Epoch 316: training loss = 0.2491, validation loss = 0.1747, patience counter = 18.
# Epoch 317: training loss = 0.2484, validation loss = 0.1749, patience counter = 19.
# Epoch 318: training loss = 0.2449, validation loss = 0.1737, patience counter = 20.
# Epoch 319: training loss = 0.2563, validation loss = 0.1742, patience counter = 21.
# Epoch 320: training loss = 0.2486, validation loss = 0.1743, patience counter = 22.
# Epoch 321: training loss = 0.2470, validation loss = 0.1741, patience counter = 23.
# Epoch 322: training loss = 0.2570, validation loss = 0.1743, patience counter = 24.
# Epoch 323: training loss = 0.2448, validation loss = 0.1743, patience counter = 25.
# Epoch 324: training loss = 0.2485, validation loss = 0.1738, patience counter = 26.
# Epoch 325: training loss = 0.2548, validation loss = 0.1744, patience counter = 27.
# Epoch 326: training loss = 0.2540, validation loss = 0.1733, patience counter = 28.
# Epoch 327: training loss = 0.2562, validation loss = 0.1741, patience counter = 29.
# Epoch 328: training loss = 0.2482, validation loss = 0.1739, patience counter = 30.
# Epoch 329: training loss = 0.2468, validation loss = 0.1738, patience counter = 31.
# Epoch 330: training loss = 0.2491, validation loss = 0.1743, patience counter = 32.
# Epoch 331: training loss = 0.2456, validation loss = 0.1745, patience counter = 33.
# Epoch 332: training loss = 0.2507, validation loss = 0.1738, patience counter = 34.
# Epoch 333: training loss = 0.2465, validation loss = 0.1739, patience counter = 35.
# Epoch 334: training loss = 0.2501, validation loss = 0.1743, patience counter = 36.
# Epoch 335: training loss = 0.2448, validation loss = 0.1739, patience counter = 37.
# Epoch 336: training loss = 0.2508, validation loss = 0.1733, patience counter = 38.
# Epoch 337: training loss = 0.2510, validation loss = 0.1730, patience counter = 0.
# Epoch 338: training loss = 0.2503, validation loss = 0.1741, patience counter = 1.
# Epoch 339: training loss = 0.2447, validation loss = 0.1739, patience counter = 2.
# Epoch 340: training loss = 0.2529, validation loss = 0.1740, patience counter = 3.
# Epoch 341: training loss = 0.2502, validation loss = 0.1741, patience counter = 4.
# Epoch 342: training loss = 0.2549, validation loss = 0.1738, patience counter = 5.
# Epoch 343: training loss = 0.2492, validation loss = 0.1749, patience counter = 6.
# Epoch 344: training loss = 0.2460, validation loss = 0.1744, patience counter = 7.
# Epoch 345: training loss = 0.2493, validation loss = 0.1735, patience counter = 8.
# Epoch 346: training loss = 0.2569, validation loss = 0.1742, patience counter = 9.
# Epoch 347: training loss = 0.2523, validation loss = 0.1744, patience counter = 10.
# Epoch 348: training loss = 0.2468, validation loss = 0.1739, patience counter = 11.
# Epoch 349: training loss = 0.2507, validation loss = 0.1749, patience counter = 12.
# Epoch 350: training loss = 0.2455, validation loss = 0.1738, patience counter = 13.
# Epoch 351: training loss = 0.2532, validation loss = 0.1739, patience counter = 14.
# Epoch 352: training loss = 0.2508, validation loss = 0.1740, patience counter = 15.
# Epoch 353: training loss = 0.2507, validation loss = 0.1740, patience counter = 16.
# Epoch 354: training loss = 0.2519, validation loss = 0.1740, patience counter = 17.
# Epoch 355: training loss = 0.2517, validation loss = 0.1732, patience counter = 18.
# Epoch 356: training loss = 0.2515, validation loss = 0.1733, patience counter = 19.
# Epoch 357: training loss = 0.2551, validation loss = 0.1748, patience counter = 20.
# Epoch 358: training loss = 0.2585, validation loss = 0.1733, patience counter = 21.
# Epoch 359: training loss = 0.2506, validation loss = 0.1741, patience counter = 22.
# Epoch 360: training loss = 0.2456, validation loss = 0.1741, patience counter = 23.
# Epoch 361: training loss = 0.2524, validation loss = 0.1736, patience counter = 24.
# Epoch 362: training loss = 0.2496, validation loss = 0.1738, patience counter = 25.
# Epoch 363: training loss = 0.2508, validation loss = 0.1739, patience counter = 26.
# Epoch 364: training loss = 0.2525, validation loss = 0.1739, patience counter = 27.
# Epoch 365: training loss = 0.2487, validation loss = 0.1740, patience counter = 28.
# Epoch 366: training loss = 0.2518, validation loss = 0.1734, patience counter = 29.
# Epoch 367: training loss = 0.2546, validation loss = 0.1746, patience counter = 30.
# Epoch 368: training loss = 0.2476, validation loss = 0.1744, patience counter = 31.
# Epoch 369: training loss = 0.2519, validation loss = 0.1731, patience counter = 32.
# Epoch 370: training loss = 0.2470, validation loss = 0.1739, patience counter = 33.
# Epoch 371: training loss = 0.2505, validation loss = 0.1742, patience counter = 34.
# Epoch 372: training loss = 0.2515, validation loss = 0.1737, patience counter = 35.
# Epoch 373: training loss = 0.2563, validation loss = 0.1737, patience counter = 36.
# Epoch 374: training loss = 0.2481, validation loss = 0.1733, patience counter = 37.
# Epoch 375: training loss = 0.2448, validation loss = 0.1741, patience counter = 38.
# Epoch 376: training loss = 0.2487, validation loss = 0.1737, patience counter = 39.
# Epoch 377: training loss = 0.2529, validation loss = 0.1732, patience counter = 40.
# Epoch 378: training loss = 0.2550, validation loss = 0.1738, patience counter = 41.
# Epoch 379: training loss = 0.2447, validation loss = 0.1743, patience counter = 42.
# Epoch 380: training loss = 0.2574, validation loss = 0.1736, patience counter = 43.
# Epoch 381: training loss = 0.2562, validation loss = 0.1738, patience counter = 44.
# Epoch 382: training loss = 0.2480, validation loss = 0.1740, patience counter = 45.
# Epoch 383: training loss = 0.2495, validation loss = 0.1736, patience counter = 46.
# Epoch 384: training loss = 0.2454, validation loss = 0.1747, patience counter = 47.
# Epoch 385: training loss = 0.2449, validation loss = 0.1740, patience counter = 48.
# Epoch 386: training loss = 0.2505, validation loss = 0.1742, patience counter = 49.
# Training stopped at epoch 387. Restoring weights from epoch 337.
# C:\Users\alled\AppData\Local\Temp\ipykernel_8024\1853304693.py:110: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.model.load_state_dict(torch.load('../data/artifacts/weights.p'))
# C:\Users\alled\AppData\Local\Temp\ipykernel_8024\797787205.py:37: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('../data/artifacts/weights.p'))
